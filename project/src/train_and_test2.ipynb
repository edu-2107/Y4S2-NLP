# %%
# !pip install transformers
# !pip uninstall numpy -y
# !pip install transformers datasets scikit-learn --upgrade
# !pip install datasets transformers scikit-learn pandas --upgrade
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Found existing installation: numpy None
# error: uninstall-no-record-file
#
# × Cannot uninstall numpy None
# ╰─> The package's contents are unknown: no RECORD file was found for numpy.
#
# hint: You might be able to recover from this via: pip install --force-reinstall --no-deps numpy==2.1.1
# ...
#   Using cached datasets-3.5.1-py3-none-any.whl.metadata (19 kB)
# ...
#   Using cached scikit_learn-1.6.1-cp311-cp311-macosx_12_0_arm64.whl.metadata (31 kB)
# ...
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# ...
#   Using cached aiohttp-3.11.18-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.7 kB)
# ...
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# ...
#   Using cached aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# ...

# %%
import pandas as pd
from datasets import Dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer, DataCollatorWithPadding
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
import torch

# Read the preprocessed dataset
df = pd.read_csv('complaints_preprocessed.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/yz/ccjsdp3x4sb_tcmc_jy2f5j00000gn/T/ipykernel_39664/3518710256.py in <cell line: 0>()
#       1 import pandas as pd
#       2 #from datasets import Dataset
# ----> 3 from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer, DataCollatorWithPadding
#       4 from sklearn.model_selection import train_test_split
#       5 from sklearn.metrics import accuracy_score, classification_report
#
# /opt/homebrew/lib/python3.11/site-packages/transformers/__init__.py in <module>
#      24
#      25 # Check the dependencies satisfy the minimal versions required.
# ---> 26 from . import dependency_versions_check
#      27 from .utils import (
#      28     OptionalDependencyNotAvailable,
#
# /opt/homebrew/lib/python3.11/site-packages/transformers/dependency_versions_check.py in <module>
# ...

# %%
df['narrative'] = df['narrative'].fillna('')
X = df['narrative']  # assuming the text column is named 'text'
y = df['Product']  # assuming the label column is named 'label'

# %%
vectorizer = TfidfVectorizer(max_features=10000)
X_vec = vectorizer.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_vec, y, test_size=0.2, random_state=42)

# %%
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Multinomial Naive Bayes": MultinomialNB(),
    "SGD Classifier": SGDClassifier(),
    "LightGBM": LGBMClassifier(),
    "Ridge Classifier": RidgeClassifier(),
    "Nearest Centroid": NearestCentroid()
}

# %%
for name, model in models.items():
    print(f"\nModel: {name}")
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred))
# Out:
# Model: Logistic Regression
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/yz/ccjsdp3x4sb_tcmc_jy2f5j00000gn/T/ipykernel_38968/473067342.py in <cell line: 0>()
#       1 for name, model in models.items():
#       2     print(f"\nModel: {name}")
# ----> 3     model.fit(X_train, y_train)
#       4     y_pred = model.predict(X_test)
#       5     print("Accuracy:", accuracy_score(y_test, y_pred))
#
# /opt/homebrew/lib/python3.11/site-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1472                 )
#    1473             ):
# -> 1474                 return fit_method(estimator, *args, **kwargs)
#    1475
#    1476         return wrapper
#
# /opt/homebrew/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1294             n_threads = 1
#    1295
# ...
