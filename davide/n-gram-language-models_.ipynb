# %% [markdown]
# Notebook prepared by Henrique Lopes Cardoso (hlc@fe.up.pt), based on [A Comprehensive Guide to Build your own Language Model in Python](https://www.analyticsvidhya.com/blog/2019/08/comprehensive-guide-language-model-nlp-python-code/) by Mohd Sanad Zaki Rizvi, and on the [Infini-gram](https://infini-gram.io/) documentation.
#
# # N-GRAM LANGUAGE MODELS
#
# N-gram language models are based on computing probabilities for the occurrence of each word given *n-1* previous words.
#
# To "train" such models, we will make use of the [Reuters](https://www.nltk.org/book/ch02.html) corpus, which contains 10,788 news documents in a total of 1.3 million words.

# %%
from nltk.corpus import reuters

# %% [markdown]
# We can check the number of sentences there are in the corpus. Each sentence is a list of words.

# %%
import nltk
nltk.download('reuters')

print(len(reuters.sents()))

print(reuters.sents()[0])
for w in reuters.sents()[0]:
    print(w, end=' ')
# Out:
# [nltk_data] Downloading package reuters to
# [nltk_data]     /Users/davideteixeira/nltk_data...
# [nltk_data]   Package reuters is already up-to-date!
# 54716
# ['ASIAN', 'EXPORTERS', 'FEAR', 'DAMAGE', 'FROM', 'U', '.', 'S', '.-', 'JAPAN', 'RIFT', 'Mounting', 'trade', 'friction', 'between', 'the', 'U', '.', 'S', '.', 'And', 'Japan', 'has', 'raised', 'fears', 'among', 'many', 'of', 'Asia', "'", 's', 'exporting', 'nations', 'that', 'the', 'row', 'could', 'inflict', 'far', '-', 'reaching', 'economic', 'damage', ',', 'businessmen', 'and', 'officials', 'said', '.']
# ASIAN EXPORTERS FEAR DAMAGE FROM U . S .- JAPAN RIFT Mounting trade friction between the U . S . And Japan has raised fears among many of Asia ' s exporting nations that the row could inflict far - reaching economic damage , businessmen and officials said .

# %% [markdown]
# ## Unigram model
#
# For starters, let's build a unigram language model.

# %%
from collections import defaultdict

# Create a placeholder for the model
uni_model = defaultdict(int)

# Count the frequency of each token
for sentence in reuters.sents():
    for w in sentence:
        uni_model[w] += 1

# %% [markdown]
# Now that we have the counts, we need to transform them into probabilities:

# %%
total_count = float(sum(uni_model.values()))
for w in uni_model:
    uni_model[w] /= total_count

# %% [markdown]
# #### Likely words
#
# How likely is the word 'the'?

# %%
# your code here
print(uni_model['the'] * total_count)
# Out:
# 58251.0

# %% [markdown]
# What is the most likely word in the corpus?

# %%
# your code here
max = 0
max_key = ""
for key in uni_model:
    if uni_model[key] > max:
        max = uni_model[key]
        max_key = key
        
print(key, uni_model[key] * total_count)
# Out:
# KRN 1.0

# %% [markdown]
# #### Generating text
#
# Based on this unigram language model, we can try generating some text. It will not be pretty, though...

# %%
import random

# number of words to generate
total_words = 100
text = []

for i in range(total_words):
    # select a random probability threshold
    r = random.random()

    # select word above the probability threshold
    accumulator = .0
    for word in uni_model.keys():
        accumulator += uni_model[word]
        if accumulator >= r:
            text.append(word)
            break

print (' '.join([t for t in text]))
# Out:
# Portugal resolved bank in added 5 31 Full an of simply . an special SERVICES " TO after without harvesting 15 fell hardline crowns 78 said qtr Bayou are Industrie in prevent FFED dlrs earnings , - 97 probable UNILEVER crucial ( new of ; the said , at 26 for tons of interest when mln John while , with the nearly in though to 15 ratification session vs L Broadcasting State this on , , / vs withdraw destroyed 244 stock PAYOUT two . for farm said 358 unexpected trade today second GY outflow common the get 8 payable

# %% [markdown]
# ## Bigram model
#
# In a bigram model, we'll compute the probability of each word given the previous word as context. To obtain bigrams, we can use NLTK's [bigrams](https://www.nltk.org/_modules/nltk/util.html#bigrams). When doing so, we can pad the input left and right and define our own sequence start and sequence end symbols.
#
# We first need to obtain the counts:

# %%
from nltk import bigrams

# Create a placeholder for the model
bi_model = defaultdict(lambda: defaultdict(lambda: 0))

# Count the frequency of each bigram
count = 0
for sentence in reuters.sents():
    for w1, w2 in bigrams(sentence, pad_right=True, pad_left=True, left_pad_symbol='<s>', right_pad_symbol='</s>'):
        bi_model[w1][w2] += 1
        count += 1

# %% [markdown]
# As before, we need to transform counts into probabilities. For that, we divide each count by the total number of occurrences of the first word in the bigram.

# %%
# your code here
from collections import defaultdict
from nltk import bigrams
from nltk.corpus import reuters

# Create a placeholder for the model
bi_model = defaultdict(lambda: defaultdict(lambda: 0))

# Count the frequency of each bigram
for sentence in reuters.sents():
    for w1, w2 in bigrams(sentence, pad_right=True, pad_left=True, left_pad_symbol='<s>', right_pad_symbol='</s>'):
        bi_model[w1][w2] += 1

# Convert counts to probabilities
for w1 in bi_model:
    total_count = sum(bi_model[w1].values())  # Total occurrences of w1
    for w2 in bi_model[w1]:
        bi_model[w1][w2] /= total_count  # Normalize

# The model now contains P(w2 | w1)

# %% [markdown]
# #### Likely pairs
#
# What are the probabilities of each word following 'today'?

# %%
# your code here
word = "today"

if word in bi_model:
    for w2, prob in bi_model[word].items():
        print(f"P({w2} | {word}) = {prob:.4f}")
else:
    print(f"No occurrences of '{word}' in the bigram model.")
# Out:
# P(. | today) = 0.1864
# P(to | today) = 0.0659
# P(' | today) = 0.1068
# P(and | today) = 0.0250
# P(as | today) = 0.0136
# P(, | today) = 0.1636
# P(with | today) = 0.0076
# P(by | today) = 0.0205
# P(when | today) = 0.0030
# P(on | today) = 0.0114
# P(recommended | today) = 0.0008
# P(he | today) = 0.0053
# P(its | today) = 0.0023
# P(for | today) = 0.0189
# P(De | today) = 0.0008
# P(European | today) = 0.0008
# P(described | today) = 0.0008
# P(the | today) = 0.0136
# P(," | today) = 0.0076
# P(they | today) = 0.0015
# P(issued | today) = 0.0015
# P(being | today) = 0.0008
# P(that | today) = 0.0333
# P(quoted | today) = 0.0045
# P(it | today) = 0.0159
# P(." | today) = 0.0038
# P(show | today) = 0.0015
# P(of | today) = 0.0098
# P(at | today) = 0.0288
# P(through | today) = 0.0015
# P(reported | today) = 0.0152
# P(( | today) = 0.0008
# P(said | today) = 0.0159
# P(in | today) = 0.0189
# P(well | today) = 0.0008
# P(is | today) = 0.0030
# P(a | today) = 0.0038
# P(because | today) = 0.0023
# P(will | today) = 0.0030
# P(are | today) = 0.0015
# P(subject | today) = 0.0008
# P(announced | today) = 0.0045
# P(discused | today) = 0.0008
# P(after | today) = 0.0121
# P(fails | today) = 0.0008
# P(rose | today) = 0.0023
# P(did | today) = 0.0015
# P(repeated | today) = 0.0015
# P(rejected | today) = 0.0015
# P(agreed | today) = 0.0008
# P(welcomed | today) = 0.0008
# P(ordered | today) = 0.0015
# P(declared | today) = 0.0015
# P(there | today) = 0.0023
# P(approved | today) = 0.0015
# P(reiterated | today) = 0.0008
# P(many | today) = 0.0008
# P(ahead | today) = 0.0008
# P(was | today) = 0.0061
# P(started | today) = 0.0008
# P(before | today) = 0.0015
# P(should | today) = 0.0008
# P(which | today) = 0.0038
# P(expects | today) = 0.0008
# P(looking | today) = 0.0008
# P(around | today) = 0.0038
# P(told | today) = 0.0008
# P(published | today) = 0.0015
# P(indicate | today) = 0.0008
# P(were | today) = 0.0053
# P(suggest | today) = 0.0008
# P(ended | today) = 0.0008
# P(into | today) = 0.0008
# P(this | today) = 0.0023
# P(urged | today) = 0.0015
# P(or | today) = 0.0030
# P(buying | today) = 0.0008
# P(called | today) = 0.0030
# P(against | today) = 0.0015
# P(received | today) = 0.0015
# P(without | today) = 0.0023
# P(slipped | today) = 0.0015
# P(while | today) = 0.0008
# P(motivated | today) = 0.0008
# P(from | today) = 0.0061
# P(except | today) = 0.0008
# P(fixed | today) = 0.0008
# P(amounts | today) = 0.0008
# P(cannot | today) = 0.0008
# P(up | today) = 0.0015
# P(Cable | today) = 0.0008
# P(delivering | today) = 0.0008
# P(releases | today) = 0.0008
# P(signed | today) = 0.0015
# P(paid | today) = 0.0008
# P(supplied | today) = 0.0008
# P(involving | today) = 0.0008
# P(higher | today) = 0.0008
# P(adjourned | today) = 0.0008
# P(would | today) = 0.0023
# P(declined | today) = 0.0008
# P(matched | today) = 0.0008
# P(partly | today) = 0.0008
# P(produced | today) = 0.0008
# P(compared | today) = 0.0015
# P(following | today) = 0.0015
# P(registered | today) = 0.0008
# P(totalled | today) = 0.0008
# P(damaged | today) = 0.0008
# P(AFG | today) = 0.0008
# P(bid | today) = 0.0008
# P(asked | today) = 0.0008
# P(calling | today) = 0.0008
# P(addresses | today) = 0.0008
# P(appointed | today) = 0.0008
# P(scrambling | today) = 0.0008
# P(Armand | today) = 0.0008
# P(310 | today) = 0.0008
# P(transmitted | today) = 0.0008
# P(reaffirmed | today) = 0.0008
# P(includes | today) = 0.0008
# P(predicted | today) = 0.0008
# P(between | today) = 0.0015
# P(set | today) = 0.0008
# P(just | today) = 0.0008
# P(closed | today) = 0.0023
# P(showed | today) = 0.0008
# P(newspapers | today) = 0.0008
# P(again | today) = 0.0008
# P(held | today) = 0.0008
# P(Hughes | today) = 0.0008
# P(formally | today) = 0.0015
# P(subsidized | today) = 0.0008
# P(suspended | today) = 0.0008
# P(began | today) = 0.0023
# P(entitled | today) = 0.0008
# P(revealed | today) = 0.0008
# P(dismissed | today) = 0.0008
# P(placed | today) = 0.0008
# P(Third | today) = 0.0008
# P(under | today) = 0.0015
# P(decided | today) = 0.0008
# P(accelerated | today) = 0.0008
# P(working | today) = 0.0008
# P(Saudi | today) = 0.0008
# P(Hungary | today) = 0.0008
# P(hold | today) = 0.0008
# P(put | today) = 0.0008
# P(sought | today) = 0.0008
# P(Kurzweil | today) = 0.0008
# P(giving | today) = 0.0008
# P(hit | today) = 0.0008
# P(clearly | today) = 0.0008
# P(repaid | today) = 0.0008
# P(hailed | today) = 0.0008
# P(opened | today) = 0.0008
# P(but | today) = 0.0030
# P(must | today) = 0.0008
# P(down | today) = 0.0015
# P(introduce | today) = 0.0008
# P(now | today) = 0.0008
# P(revived | today) = 0.0008
# P(so | today) = 0.0008
# P(met | today) = 0.0008
# P(included | today) = 0.0008
# P(denied | today) = 0.0008
# P(Greek | today) = 0.0008
# P(lodged | today) = 0.0008
# P(joined | today) = 0.0008
# P(their | today) = 0.0008
# P(MTS | today) = 0.0008
# P(along | today) = 0.0008
# P(Iran | today) = 0.0008
# P(appeared | today) = 0.0008
# P(saying | today) = 0.0008
# P(foreign | today) = 0.0008
# P(vowed | today) = 0.0008
# P(GenCorp | today) = 0.0008
# P(near | today) = 0.0008
# P(brought | today) = 0.0008
# P(indicated | today) = 0.0008
# P(onward | today) = 0.0008
# P(publish | today) = 0.0008

# %% [markdown]
# What are the probabilities for sentence-starting words? What do most of them have in common? (Hint: check the *left_pad_symbol* defined above for collecting bigrams.)

# %%
# your code here
start_symbol = "<s>"

if start_symbol in bi_model:
    for w2, prob in sorted(bi_model[start_symbol].items(), key=lambda x: x[1], reverse=True):
        print(f"P({w2} | {start_symbol}) = {prob:.4f}")
else:
    print("No sentence-starting words found in the bigram model.")
# Out:
# P(The | <s>) = 0.1615
# P(" | <s>) = 0.0656
# P(It | <s>) = 0.0323
# P(He | <s>) = 0.0290
# P(In | <s>) = 0.0252
# P(But | <s>) = 0.0193
# P(U | <s>) = 0.0158
# P(A | <s>) = 0.0140
# P(This | <s>) = 0.0082
# P(They | <s>) = 0.0082
# P(However | <s>) = 0.0072
# P(& | <s>) = 0.0057
# P(Under | <s>) = 0.0046
# P(For | <s>) = 0.0038
# P(Analysts | <s>) = 0.0037
# P(Last | <s>) = 0.0037
# P(On | <s>) = 0.0037
# P(As | <s>) = 0.0037
# P(At | <s>) = 0.0035
# P(Some | <s>) = 0.0032
# P(If | <s>) = 0.0032
# P(There | <s>) = 0.0031
# P(JAPAN | <s>) = 0.0030
# P(Earlier | <s>) = 0.0029
# P(FED | <s>) = 0.0029
# P(1986 | <s>) = 0.0028
# P(One | <s>) = 0.0027
# P(An | <s>) = 0.0026
# P(Terms | <s>) = 0.0025
# P(USDA | <s>) = 0.0025
# P(EC | <s>) = 0.0024
# P(Net | <s>) = 0.0024
# P(Asked | <s>) = 0.0023
# P(Dealers | <s>) = 0.0021
# P(Japan | <s>) = 0.0020
# P(Total | <s>) = 0.0020
# P(Other | <s>) = 0.0020
# P(BANK | <s>) = 0.0020
# P(That | <s>) = 0.0019
# P(While | <s>) = 0.0019
# P(AMERICAN | <s>) = 0.0018
# P(Although | <s>) = 0.0017
# P(No | <s>) = 0.0017
# P(CANADA | <s>) = 0.0017
# P(FIRST | <s>) = 0.0016
# P(Its | <s>) = 0.0016
# P(Bank | <s>) = 0.0016
# P(1985 | <s>) = 0.0015
# P(After | <s>) = 0.0015
# P(These | <s>) = 0.0015
# P(Another | <s>) = 0.0014
# P(Most | <s>) = 0.0014
# P(Exports | <s>) = 0.0014
# P(We | <s>) = 0.0013
# P(Traders | <s>) = 0.0013
# P(Baker | <s>) = 0.0013
# P(Both | <s>) = 0.0013
# P(To | <s>) = 0.0012
# P(She | <s>) = 0.0012
# P(American | <s>) = 0.0012
# P(Since | <s>) = 0.0012
# P(NEW | <s>) = 0.0011
# P(All | <s>) = 0.0011
# P(I | <s>) = 0.0011
# P(Sales | <s>) = 0.0011
# P(And | <s>) = 0.0011
# P(Economists | <s>) = 0.0011
# P(Yesterday | <s>) = 0.0011
# P(With | <s>) = 0.0011
# P(Officials | <s>) = 0.0011
# P(TWA | <s>) = 0.0011
# P(Among | <s>) = 0.0010
# P(According | <s>) = 0.0010
# P(FRENCH | <s>) = 0.0010
# P(Prior | <s>) = 0.0010
# P(N | <s>) = 0.0010
# P(GERMAN | <s>) = 0.0010
# P(Foreign | <s>) = 0.0010
# P(Oil | <s>) = 0.0010
# P(NATIONAL | <s>) = 0.0010
# P(Today | <s>) = 0.0010
# P(BP | <s>) = 0.0010
# P(Company | <s>) = 0.0010
# P(Current | <s>) = 0.0010
# P(General | <s>) = 0.0010
# P(TAIWAN | <s>) = 0.0010
# P(Trade | <s>) = 0.0010
# P(Production | <s>) = 0.0010
# P(- | <s>) = 0.0010
# P(TREASURY | <s>) = 0.0009
# P(CHINA | <s>) = 0.0009
# P(Imports | <s>) = 0.0009
# P(First | <s>) = 0.0009
# P(Dlrs | <s>) = 0.0009
# P(President | <s>) = 0.0009
# P(Yeutter | <s>) = 0.0009
# P(Soybean | <s>) = 0.0009
# P(Also | <s>) = 0.0009
# P(Despite | <s>) = 0.0009
# P(1987 | <s>) = 0.0009
# P(Year | <s>) = 0.0008
# P(About | <s>) = 0.0008
# P(( | <s>) = 0.0008
# P(Japanese | <s>) = 0.0008
# P(NOTE | <s>) = 0.0008
# P(Prices | <s>) = 0.0008
# P(New | <s>) = 0.0008
# P(Speaking | <s>) = 0.0008
# P(During | <s>) = 0.0008
# P(Dome | <s>) = 0.0008
# P(GENERAL | <s>) = 0.0008
# P(Finance | <s>) = 0.0008
# P(M | <s>) = 0.0008
# P(Meanwhile | <s>) = 0.0007
# P(CANADIAN | <s>) = 0.0007
# P(Many | <s>) = 0.0007
# P(USAir | <s>) = 0.0007
# P(Bankers | <s>) = 0.0007
# P(When | <s>) = 0.0007
# P(REUTER | <s>) = 0.0007
# P(Sumita | <s>) = 0.0007
# P(Of | <s>) = 0.0007
# P(Lawson | <s>) = 0.0007
# P(Domestic | <s>) = 0.0007
# P(Taiwan | <s>) = 0.0007
# P(Stoltenberg | <s>) = 0.0007
# P(BRAZIL | <s>) = 0.0007
# P(Ecuador | <s>) = 0.0007
# P(National | <s>) = 0.0007
# P(German | <s>) = 0.0007
# P(Commenting | <s>) = 0.0007
# P(More | <s>) = 0.0007
# P(AUSTRALIAN | <s>) = 0.0007
# P(De | <s>) = 0.0007
# P(Such | <s>) = 0.0007
# P(Results | <s>) = 0.0007
# P(SOUTH | <s>) = 0.0007
# P(Brazil | <s>) = 0.0007
# P(UK | <s>) = 0.0007
# P(UNITED | <s>) = 0.0007
# P(Reagan | <s>) = 0.0007
# P(Money | <s>) = 0.0007
# P(Note | <s>) = 0.0007
# P(Industry | <s>) = 0.0007
# P(By | <s>) = 0.0007
# P(British | <s>) = 0.0007
# P(GENCORP | <s>) = 0.0007
# P(EXPORTERS | <s>) = 0.0006
# P(OPEC | <s>) = 0.0006
# P(Indonesia | <s>) = 0.0006
# P(Banks | <s>) = 0.0006
# P(West | <s>) = 0.0006
# P(CCC | <s>) = 0.0006
# P(Shr | <s>) = 0.0006
# P(Miyazawa | <s>) = 0.0006
# P(China | <s>) = 0.0006
# P(S | <s>) = 0.0006
# P(INDIA | <s>) = 0.0006
# P(Government | <s>) = 0.0006
# P(DUTCH | <s>) = 0.0006
# P(Only | <s>) = 0.0006
# P(Wheat | <s>) = 0.0006
# P(Producers | <s>) = 0.0006
# P(Several | <s>) = 0.0006
# P(Each | <s>) = 0.0006
# P(His | <s>) = 0.0005
# P(INTERNATIONAL | <s>) = 0.0005
# P(Federal | <s>) = 0.0005
# P(Lyng | <s>) = 0.0005
# P(API | <s>) = 0.0005
# P(Canadian | <s>) = 0.0005
# P(GAF | <s>) = 0.0005
# P(Bundesbank | <s>) = 0.0005
# P(SAUDI | <s>) = 0.0005
# P(February | <s>) = 0.0005
# P(World | <s>) = 0.0005
# P(Following | <s>) = 0.0005
# P(Sosnoff | <s>) = 0.0005
# P(VOLCKER | <s>) = 0.0005
# P(South | <s>) = 0.0005
# P(Output | <s>) = 0.0005
# P(J | <s>) = 0.0005
# P(Revenues | <s>) = 0.0005
# P(GROUP | <s>) = 0.0005
# P(Full | <s>) = 0.0005
# P(French | <s>) = 0.0005
# P(Saudi | <s>) = 0.0005
# P(Gold | <s>) = 0.0005
# P(Delegates | <s>) = 0.0005
# P(Market | <s>) = 0.0005
# P(Western | <s>) = 0.0005
# P(GREAT | <s>) = 0.0005
# P(Because | <s>) = 0.0005
# P(Consumer | <s>) = 0.0005
# P(Over | <s>) = 0.0005
# P(Poehl | <s>) = 0.0005
# P(UNION | <s>) = 0.0005
# P(Previously | <s>) = 0.0005
# P(Central | <s>) = 0.0005
# P(-- | <s>) = 0.0005
# P(Two | <s>) = 0.0005
# P(Parent | <s>) = 0.0005
# P(Earnings | <s>) = 0.0005
# P(Washington | <s>) = 0.0005
# P(Any | <s>) = 0.0005
# P(Crude | <s>) = 0.0005
# P(BAKER | <s>) = 0.0005
# P(Even | <s>) = 0.0005
# P(GenCorp | <s>) = 0.0005
# P(Trading | <s>) = 0.0004
# P(BUNDESBANK | <s>) = 0.0004
# P(Non | <s>) = 0.0004
# P(Turnover | <s>) = 0.0004
# P(LAWSON | <s>) = 0.0004
# P(ROYAL | <s>) = 0.0004
# P(NO | <s>) = 0.0004
# P(Based | <s>) = 0.0004
# P(SOVIET | <s>) = 0.0004
# P(Hutton | <s>) = 0.0004
# P(GRAIN | <s>) = 0.0004
# P(ECUADOR | <s>) = 0.0004
# P(Merrill | <s>) = 0.0004
# P(H | <s>) = 0.0004
# P(YEUTTER | <s>) = 0.0004
# P(Dixons | <s>) = 0.0004
# P(CPC | <s>) = 0.0004
# P(Dart | <s>) = 0.0004
# P(Share | <s>) = 0.0004
# P(CORRECTED | <s>) = 0.0004
# P(Union | <s>) = 0.0004
# P(So | <s>) = 0.0004
# P(CSR | <s>) = 0.0004
# P(E | <s>) = 0.0004
# P(Private | <s>) = 0.0004
# P(EXPORT | <s>) = 0.0004
# P(STANDARD | <s>) = 0.0004
# P(INVESTOR | <s>) = 0.0004
# P(FRANKLIN | <s>) = 0.0004
# P(REAGAN | <s>) = 0.0004
# P(INDONESIA | <s>) = 0.0004
# P(Now | <s>) = 0.0004
# P(Agriculture | <s>) = 0.0004
# P(COCOA | <s>) = 0.0004
# P(ARGENTINE | <s>) = 0.0004
# P(LONDON | <s>) = 0.0004
# P(TEXAS | <s>) = 0.0004
# P(Fed | <s>) = 0.0004
# P(BRITISH | <s>) = 0.0004
# P(USAIR | <s>) = 0.0004
# P(P | <s>) = 0.0004
# P(Commerce | <s>) = 0.0004
# P(GULF | <s>) = 0.0004
# P(ICCO | <s>) = 0.0004
# P(ECONOMIC | <s>) = 0.0004
# P(COMPUTER | <s>) = 0.0004
# P(International | <s>) = 0.0004
# P(Continental | <s>) = 0.0004
# P(SWISS | <s>) = 0.0004
# P(Grain | <s>) = 0.0004
# P(Sterling | <s>) = 0.0004
# P(ALLIED | <s>) = 0.0004
# P(Growth | <s>) = 0.0004
# P(Allied | <s>) = 0.0004
# P(Between | <s>) = 0.0004
# P(Currently | <s>) = 0.0004
# P(INVESTMENT | <s>) = 0.0004
# P(IRAN | <s>) = 0.0004
# P(Santos | <s>) = 0.0004
# P(Cents | <s>) = 0.0004
# P(Herrington | <s>) = 0.0004
# P(THAI | <s>) = 0.0003
# P(NORTH | <s>) = 0.0003
# P(European | <s>) = 0.0003
# P(Unadjusted | <s>) = 0.0003
# P(Operating | <s>) = 0.0003
# P(Taft | <s>) = 0.0003
# P(Standard | <s>) = 0.0003
# P(BALDRIGE | <s>) = 0.0003
# P(SHELL | <s>) = 0.0003
# P(Canada | <s>) = 0.0003
# P(Coffee | <s>) = 0.0003
# P(ICO | <s>) = 0.0003
# P(Official | <s>) = 0.0003
# P(Morgan | <s>) = 0.0003
# P(TALKING | <s>) = 0.0003
# P(CHRYSLER | <s>) = 0.0003
# P(Proceeds | <s>) = 0.0003
# P(Their | <s>) = 0.0003
# P(London | <s>) = 0.0003
# P(WORLD | <s>) = 0.0003
# P(SPAIN | <s>) = 0.0003
# P(DIAMOND | <s>) = 0.0003
# P(DOLLAR | <s>) = 0.0003
# P(Corn | <s>) = 0.0003
# P(Borg | <s>) = 0.0003
# P(ALLEGHENY | <s>) = 0.0003
# P(Nakasone | <s>) = 0.0003
# P(January | <s>) = 0.0003
# P(Industrial | <s>) = 0.0003
# P(MALAYSIA | <s>) = 0.0003
# P(ITALY | <s>) = 0.0003
# P(Further | <s>) = 0.0003
# P(Harcourt | <s>) = 0.0003
# P(COLOMBIA | <s>) = 0.0003
# P(GATT | <s>) = 0.0003
# P(PAKISTAN | <s>) = 0.0003
# P(MORE | <s>) = 0.0003
# P(Dividend | <s>) = 0.0003
# P(Malaysia | <s>) = 0.0003
# P(MIYAZAWA | <s>) = 0.0003
# P(C | <s>) = 0.0003
# P(Soviet | <s>) = 0.0003
# P(Brown | <s>) = 0.0003
# P(Farmers | <s>) = 0.0003
# P(USX | <s>) = 0.0003
# P(WHEAT | <s>) = 0.0003
# P(Interest | <s>) = 0.0003
# P(Inflation | <s>) = 0.0003
# P(Gross | <s>) = 0.0003
# P(Robert | <s>) = 0.0003
# P(Diplomats | <s>) = 0.0003
# P(Closing | <s>) = 0.0003
# P(VENEZUELA | <s>) = 0.0003
# P(Within | <s>) = 0.0003
# P(Nazer | <s>) = 0.0003
# P(K | <s>) = 0.0003
# P(Australia | <s>) = 0.0003
# P(JAPANESE | <s>) = 0.0003
# P(SUN | <s>) = 0.0003
# P(Iraq | <s>) = 0.0003
# P(Spot | <s>) = 0.0003
# P(Purolator | <s>) = 0.0003
# P(April | <s>) = 0.0003
# P(WASTE | <s>) = 0.0003
# P(BELGIAN | <s>) = 0.0003
# P(WALL | <s>) = 0.0003
# P(Prime | <s>) = 0.0003
# P(Britain | <s>) = 0.0003
# P(Six | <s>) = 0.0003
# P(Reynolds | <s>) = 0.0003
# P(OECD | <s>) = 0.0003
# P(Shell | <s>) = 0.0003
# P(Rep | <s>) = 0.0003
# P(Those | <s>) = 0.0003
# P(IBC | <s>) = 0.0003
# P(David | <s>) = 0.0003
# P(Woolworth | <s>) = 0.0003
# P(Capital | <s>) = 0.0003
# P(ChemLawn | <s>) = 0.0003
# P(Until | <s>) = 0.0003
# P(Kuwait | <s>) = 0.0003
# P(Chairman | <s>) = 0.0003
# P(UAL | <s>) = 0.0003
# P(Energy | <s>) = 0.0003
# P(Chrysler | <s>) = 0.0003
# P(COFFEE | <s>) = 0.0003
# P(Gasoline | <s>) = 0.0003
# P(Without | <s>) = 0.0003
# P(Currency | <s>) = 0.0003
# P(Final | <s>) = 0.0003
# P(WEST | <s>) = 0.0003
# P(Payment | <s>) = 0.0003
# P(May | <s>) = 0.0003
# P(BROWN | <s>) = 0.0003
# P(BRAZILIAN | <s>) = 0.0003
# P(Analyst | <s>) = 0.0003
# P(Overall | <s>) = 0.0003
# P(CENTRAL | <s>) = 0.0003
# P(HOUSE | <s>) = 0.0003
# P(Banking | <s>) = 0.0003
# P(SINGAPORE | <s>) = 0.0003
# P(TRADE | <s>) = 0.0003
# P(Bond | <s>) = 0.0003
# P(ITALIAN | <s>) = 0.0003
# P(Recent | <s>) = 0.0003
# P(DIXONS | <s>) = 0.0003
# P(PERU | <s>) = 0.0003
# P(Neither | <s>) = 0.0003
# P(HUGHES | <s>) = 0.0003
# P(Late | <s>) = 0.0003
# P(Seasonally | <s>) = 0.0003
# P(Latest | <s>) = 0.0003
# P(BHP | <s>) = 0.0003
# P(Partly | <s>) = 0.0003
# P(Shearson | <s>) = 0.0003
# P(Sorghum | <s>) = 0.0003
# P(Volcker | <s>) = 0.0003
# P(G | <s>) = 0.0003
# P(Separately | <s>) = 0.0003
# P(PHILIPPINE | <s>) = 0.0003
# P(Price | <s>) = 0.0003
# P(MAJOR | <s>) = 0.0003
# P(Call | <s>) = 0.0003
# P(FRANCE | <s>) = 0.0003
# P(TAFT | <s>) = 0.0003
# P(SOYBEAN | <s>) = 0.0003
# P(KUWAIT | <s>) = 0.0003
# P(Texaco | <s>) = 0.0003
# P(BANGLADESH | <s>) = 0.0003
# P(Before | <s>) = 0.0003
# P(Colombia | <s>) = 0.0003
# P(Figures | <s>) = 0.0003
# P(THE | <s>) = 0.0003
# P(Honeywell | <s>) = 0.0003
# P(Talks | <s>) = 0.0003
# P(Baldrige | <s>) = 0.0003
# P(Dollars | <s>) = 0.0003
# P(Manufacturing | <s>) = 0.0003
# P(Exxon | <s>) = 0.0003
# P(Consumers | <s>) = 0.0003
# P(Gencorp | <s>) = 0.0003
# P(Emery | <s>) = 0.0003
# P(Thailand | <s>) = 0.0002
# P(Wilson | <s>) = 0.0002
# P(Shareholders | <s>) = 0.0002
# P(NIPPON | <s>) = 0.0002
# P(Consolidated | <s>) = 0.0002
# P(HOME | <s>) = 0.0002
# P(Burlington | <s>) = 0.0002
# P(EIA | <s>) = 0.0002
# P(DOME | <s>) = 0.0002
# P(Three | <s>) = 0.0002
# P(Chase | <s>) = 0.0002
# P(Tokyo | <s>) = 0.0002
# P(FORD | <s>) = 0.0002
# P(Cotton | <s>) = 0.0002
# P(USSR | <s>) = 0.0002
# P(MOBIL | <s>) = 0.0002
# P(TEXACO | <s>) = 0.0002
# P(TransCanada | <s>) = 0.0002
# P(Noting | <s>) = 0.0002
# P(Moreover | <s>) = 0.0002
# P(Johnson | <s>) = 0.0002
# P(Nippon | <s>) = 0.0002
# P(B | <s>) = 0.0002
# P(Instead | <s>) = 0.0002
# P(DART | <s>) = 0.0002
# P(Norway | <s>) = 0.0002
# P(HENLEY | <s>) = 0.0002
# P(Attack | <s>) = 0.0002
# P(Conable | <s>) = 0.0002
# P(Gulf | <s>) = 0.0002
# P(Amstutz | <s>) = 0.0002
# P(Rha | <s>) = 0.0002
# P(MITI | <s>) = 0.0002
# P(Export | <s>) = 0.0002
# P(INDONESIAN | <s>) = 0.0002
# P(Intervention | <s>) = 0.0002
# P(WOOLWORTH | <s>) = 0.0002
# P(Monetary | <s>) = 0.0002
# P(CONTINENTAL | <s>) = 0.0002
# P(ENERGY | <s>) = 0.0002
# P(Major | <s>) = 0.0002
# P(said | <s>) = 0.0002
# P(Given | <s>) = 0.0002
# P(3 | <s>) = 0.0002
# P(Pre | <s>) = 0.0002
# P(Group | <s>) = 0.0002
# P(CONSOLIDATED | <s>) = 0.0002
# P(Completion | <s>) = 0.0002
# P(Holders | <s>) = 0.0002
# P(FINANCIAL | <s>) = 0.0002
# P(Cable | <s>) = 0.0002
# P(MERRILL | <s>) = 0.0002
# P(FEDERAL | <s>) = 0.0002
# P(US | <s>) = 0.0002
# P(AMOCO | <s>) = 0.0002
# P(SOUTHERN | <s>) = 0.0002
# P(AUSTRALIA | <s>) = 0.0002
# P(Royal | <s>) = 0.0002
# P(Economist | <s>) = 0.0002
# P(TURKISH | <s>) = 0.0002
# P(Richard | <s>) = 0.0002
# P(Lukman | <s>) = 0.0002
# P(Iran | <s>) = 0.0002
# P(CYCLOPS | <s>) = 0.0002
# P(SWEDEN | <s>) = 0.0002
# P(TMOC | <s>) = 0.0002
# P(Redstone | <s>) = 0.0002
# P(Hughes | <s>) = 0.0002
# P(CHEMLAWN | <s>) = 0.0002
# P(AMC | <s>) = 0.0002
# P(Others | <s>) = 0.0002
# P(High | <s>) = 0.0002
# P(Nine | <s>) = 0.0002
# P(Cumulative | <s>) = 0.0002
# P(Excluding | <s>) = 0.0002
# P(Wall | <s>) = 0.0002
# P(WHITE | <s>) = 0.0002
# P(DOW | <s>) = 0.0002
# P(the | <s>) = 0.0002
# P(Though | <s>) = 0.0002
# P(India | <s>) = 0.0002
# P(Cattle | <s>) = 0.0002
# P(Sharp | <s>) = 0.0002
# P(HANSON | <s>) = 0.0002
# P(EXXON | <s>) = 0.0002
# P(FEDERATED | <s>) = 0.0002
# P(NORANDA | <s>) = 0.0002
# P(Retail | <s>) = 0.0002
# P(Combined | <s>) = 0.0002
# P(Still | <s>) = 0.0002
# P(From | <s>) = 0.0002
# P(Senior | <s>) = 0.0002
# P(BORG | <s>) = 0.0002
# P(Treasury | <s>) = 0.0002
# P(Ministers | <s>) = 0.0002
# P(United | <s>) = 0.0002
# P(Brazilian | <s>) = 0.0002
# P(HONG | <s>) = 0.0002
# P(LYNG | <s>) = 0.0002
# P(Dollar | <s>) = 0.0002
# P(Shares | <s>) = 0.0002
# P(Cash | <s>) = 0.0002
# P(CHARTER | <s>) = 0.0002
# P(James | <s>) = 0.0002
# P(VIACOM | <s>) = 0.0002
# P(Smith | <s>) = 0.0002
# P(MAY | <s>) = 0.0002
# P(COASTAL | <s>) = 0.0002
# P(Light | <s>) = 0.0002
# P(IRAQ | <s>) = 0.0002
# P(PDVSA | <s>) = 0.0002
# P(Hernandez | <s>) = 0.0002
# P(CAMPBELL | <s>) = 0.0002
# P(Allegheny | <s>) = 0.0002
# P(BANKAMERICA | <s>) = 0.0002
# P(Caesars | <s>) = 0.0002
# P(Comdata | <s>) = 0.0002
# P(Xuto | <s>) = 0.0002
# P(KLM | <s>) = 0.0002
# P(Petrobras | <s>) = 0.0002
# P(BAT | <s>) = 0.0002
# P(CRA | <s>) = 0.0002
# P(CONRAC | <s>) = 0.0002
# P(SWEDISH | <s>) = 0.0002
# P(BANKERS | <s>) = 0.0002
# P(F | <s>) = 0.0002
# P(Maize | <s>) = 0.0002
# P(DATA | <s>) = 0.0002
# P(Congressional | <s>) = 0.0002
# P(House | <s>) = 0.0002
# P(SECURITY | <s>) = 0.0002
# P(EGYPT | <s>) = 0.0002
# P(Commercial | <s>) = 0.0002
# P(Labour | <s>) = 0.0002
# P(Noranda | <s>) = 0.0002
# P(FHLBB | <s>) = 0.0002
# P(Details | <s>) = 0.0002
# P(Financial | <s>) = 0.0002
# P(Sources | <s>) = 0.0002
# P(Sprinkel | <s>) = 0.0002
# P(Stocks | <s>) = 0.0002
# P(Australian | <s>) = 0.0002
# P(Average | <s>) = 0.0002
# P(Reuter | <s>) = 0.0002
# P(State | <s>) = 0.0002
# P(Wang | <s>) = 0.0002
# P(ANZ | <s>) = 0.0002
# P(COMMONWEALTH | <s>) = 0.0002
# P(NCR | <s>) = 0.0002
# P(CHEMICAL | <s>) = 0.0002
# P(Henderson | <s>) = 0.0002
# P(Conger | <s>) = 0.0002
# P(Orders | <s>) = 0.0002
# P(MARINE | <s>) = 0.0002
# P(Fourth | <s>) = 0.0002
# P(Loans | <s>) = 0.0002
# P(JOHN | <s>) = 0.0002
# P(White | <s>) = 0.0002
# P(ENTERTAINMENT | <s>) = 0.0002
# P(Members | <s>) = 0.0002
# P(Speculation | <s>) = 0.0002
# P(Besides | <s>) = 0.0002
# P(Computer | <s>) = 0.0002
# P(Azpurua | <s>) = 0.0002
# P(Van | <s>) = 0.0002
# P(ALCAN | <s>) = 0.0002
# P(ARCO | <s>) = 0.0002
# P(Sen | <s>) = 0.0002
# P(Balladur | <s>) = 0.0002
# P(Gillette | <s>) = 0.0002
# P(UNOCAL | <s>) = 0.0002
# P(Local | <s>) = 0.0002
# P(Leigh | <s>) = 0.0002
# P(OIL | <s>) = 0.0002
# P(NORWAY | <s>) = 0.0002
# P(Venezuela | <s>) = 0.0002
# P(Citicorp | <s>) = 0.0002
# P(HUDSON | <s>) = 0.0002
# P(Four | <s>) = 0.0002
# P(Business | <s>) = 0.0002
# P(Newmont | <s>) = 0.0002
# P(HARPER | <s>) = 0.0002
# P(Profits | <s>) = 0.0002
# P(LEADING | <s>) = 0.0002
# P(Turning | <s>) = 0.0002
# P(Cyclops | <s>) = 0.0002
# P(Shipments | <s>) = 0.0002
# P(CAESARS | <s>) = 0.0002
# P(Piedmont | <s>) = 0.0002
# P(ICI | <s>) = 0.0002
# P(Sheikh | <s>) = 0.0002
# P(Pesch | <s>) = 0.0002
# P(Cyacq | <s>) = 0.0002
# P(Nogales | <s>) = 0.0002
# P(Fleet | <s>) = 0.0002
# P(McIvor | <s>) = 0.0002
# P(Huckaby | <s>) = 0.0002
# P(Indonesian | <s>) = 0.0002
# P(SRI | <s>) = 0.0002
# P(Kim | <s>) = 0.0002
# P(Jardine | <s>) = 0.0002
# P(SAN | <s>) = 0.0002
# P(STOLTENBERG | <s>) = 0.0002
# P(Out | <s>) = 0.0002
# P(VW | <s>) = 0.0002
# P(UNIVERSAL | <s>) = 0.0002
# P(Ministry | <s>) = 0.0002
# P(Upon | <s>) = 0.0002
# P(Later | <s>) = 0.0002
# P(Carney | <s>) = 0.0002
# P(WILLIAMS | <s>) = 0.0002
# P(Williams | <s>) = 0.0002
# P(1 | <s>) = 0.0002
# P(RIO | <s>) = 0.0002
# P(Extraordinary | <s>) = 0.0002
# P(CARGILL | <s>) = 0.0002
# P(Assets | <s>) = 0.0002
# P(WASHINGTON | <s>) = 0.0002
# P(HOG | <s>) = 0.0002
# P(Schlesinger | <s>) = 0.0002
# P(Actual | <s>) = 0.0002
# P(Peter | <s>) = 0.0002
# P(NORTHERN | <s>) = 0.0002
# P(DOE | <s>) = 0.0002
# P(X | <s>) = 0.0002
# P(Including | <s>) = 0.0002
# P(OHIO | <s>) = 0.0002
# P(Great | <s>) = 0.0002
# P(Gabelli | <s>) = 0.0002
# P(ST | <s>) = 0.0002
# P(Statoil | <s>) = 0.0002
# P(Once | <s>) = 0.0002
# P(Brokers | <s>) = 0.0002
# P(GOODYEAR | <s>) = 0.0002
# P(Backlog | <s>) = 0.0002
# P(O | <s>) = 0.0002
# P(GTE | <s>) = 0.0002
# P(Elders | <s>) = 0.0002
# P(Paul | <s>) = 0.0002
# P(TOTAL | <s>) = 0.0002
# P(PHILLIPS | <s>) = 0.0002
# P(COURT | <s>) = 0.0002
# P(NAKASONE | <s>) = 0.0002
# P(DANISH | <s>) = 0.0002
# P(Growers | <s>) = 0.0002
# P(SERVICE | <s>) = 0.0002
# P(MURPHY | <s>) = 0.0002
# P(MARATHON | <s>) = 0.0002
# P(Dutch | <s>) = 0.0002
# P(Top | <s>) = 0.0002
# P(PACIFIC | <s>) = 0.0002
# P(Lower | <s>) = 0.0002
# P(MANUFACTURERS | <s>) = 0.0002
# P(Fiscal | <s>) = 0.0002
# P(Funds | <s>) = 0.0002
# P(CHASE | <s>) = 0.0002
# P(Weinberger | <s>) = 0.0002
# P(IC | <s>) = 0.0002
# P(Natural | <s>) = 0.0002
# P(26 | <s>) = 0.0002
# P(Bra | <s>) = 0.0002
# P(BIL | <s>) = 0.0002
# P(Negotiations | <s>) = 0.0002
# P(BASF | <s>) = 0.0002
# P(Glickman | <s>) = 0.0002
# P(CYACQ | <s>) = 0.0002
# P(), | <s>) = 0.0002
# P(MTS | <s>) = 0.0002
# P(Much | <s>) = 0.0001
# P(Deputy | <s>) = 0.0001
# P(WESTERN | <s>) = 0.0001
# P(Position | <s>) = 0.0001
# P(Citibank | <s>) = 0.0001
# P(Unilever | <s>) = 0.0001
# P(INTERVENTION | <s>) = 0.0001
# P(Security | <s>) = 0.0001
# P(ZAMBIA | <s>) = 0.0001
# P(Finally | <s>) = 0.0001
# P(Trump | <s>) = 0.0001
# P(France | <s>) = 0.0001
# P(Arbitragers | <s>) = 0.0001
# P(MELLON | <s>) = 0.0001
# P(TURKEY | <s>) = 0.0001
# P(Turkey | <s>) = 0.0001
# P(Heller | <s>) = 0.0001
# P(Miller | <s>) = 0.0001
# P(Diplomatic | <s>) = 0.0001
# P(BELGIUM | <s>) = 0.0001
# P(AEGON | <s>) = 0.0001
# P(EUROPEAN | <s>) = 0.0001
# P(HEALTH | <s>) = 0.0001
# P(Small | <s>) = 0.0001
# P(Five | <s>) = 0.0001
# P(Southmark | <s>) = 0.0001
# P(Representatives | <s>) = 0.0001
# P(REPUBLIC | <s>) = 0.0001
# P(WESTINGHOUSE | <s>) = 0.0001
# P(Mexico | <s>) = 0.0001
# P(ASSETS | <s>) = 0.0001
# P(FIRM | <s>) = 0.0001
# P(ANALYSTS | <s>) = 0.0001
# P(Italy | <s>) = 0.0001
# P(SOSNOFF | <s>) = 0.0001
# P(ROTTERDAM | <s>) = 0.0001
# P(Chemical | <s>) = 0.0001
# P(Clark | <s>) = 0.0001
# P(Balances | <s>) = 0.0001
# P(Construction | <s>) = 0.0001
# P(PIONEER | <s>) = 0.0001
# P(Imperial | <s>) = 0.0001
# P(ICN | <s>) = 0.0001
# P(Spokesman | <s>) = 0.0001
# P(Oper | <s>) = 0.0001
# P(Second | <s>) = 0.0001
# P(TOKYO | <s>) = 0.0001
# P(Additionally | <s>) = 0.0001
# P(Bilzerian | <s>) = 0.0001
# P(SUPERMARKETS | <s>) = 0.0001
# P(BASS | <s>) = 0.0001
# P(INVESTORS | <s>) = 0.0001
# P(HARCOURT | <s>) = 0.0001
# P(ETL | <s>) = 0.0001
# P(MEES | <s>) = 0.0001
# P(Amoco | <s>) = 0.0001
# P(Furthermore | <s>) = 0.0001
# P(Texas | <s>) = 0.0001
# P(Unemployment | <s>) = 0.0001
# P(AGENCY | <s>) = 0.0001
# P(Senate | <s>) = 0.0001
# P(Chartered | <s>) = 0.0001
# P(Jacobs | <s>) = 0.0001
# P(Pacific | <s>) = 0.0001
# P(and | <s>) = 0.0001
# P(SEC | <s>) = 0.0001
# P(Dauster | <s>) = 0.0001
# P(SUMITA | <s>) = 0.0001
# P(PHILIPPINES | <s>) = 0.0001
# P(Aqazadeh | <s>) = 0.0001
# P(TRANS | <s>) = 0.0001
# P(SANTA | <s>) = 0.0001
# P(Simon | <s>) = 0.0001
# P(WTI | <s>) = 0.0001
# P(Viacom | <s>) = 0.0001
# P(Early | <s>) = 0.0001
# P(Yulo | <s>) = 0.0001
# P(TWO | <s>) = 0.0001
# P(Danforth | <s>) = 0.0001
# P(Lindner | <s>) = 0.0001
# P(KANSAS | <s>) = 0.0001
# P(Employment | <s>) = 0.0001
# P(HARRIS | <s>) = 0.0001
# P(Bayer | <s>) = 0.0001
# P(Icahn | <s>) = 0.0001
# P(Kistler | <s>) = 0.0001
# P(Resorts | <s>) = 0.0001
# P(HEINZ | <s>) = 0.0001
# P(ALUSUISSE | <s>) = 0.0001
# P(NORSTAR | <s>) = 0.0001
# P(Denman | <s>) = 0.0001
# P(Wendy | <s>) = 0.0001
# P(Concepcion | <s>) = 0.0001
# P(End | <s>) = 0.0001
# P(Profit | <s>) = 0.0001
# P(CITIBANK | <s>) = 0.0001
# P(Spain | <s>) = 0.0001
# P(Michael | <s>) = 0.0001
# P(Reserve | <s>) = 0.0001
# P(POEHL | <s>) = 0.0001
# P(UNILEVER | <s>) = 0.0001
# P(Mark | <s>) = 0.0001
# P(Conrac | <s>) = 0.0001
# P(ELECTRO | <s>) = 0.0001
# P(SOUTHMARK | <s>) = 0.0001
# P(Demand | <s>) = 0.0001
# P(Houston | <s>) = 0.0001
# P(FLEET | <s>) = 0.0001
# P(2 | <s>) = 0.0001
# P(Offers | <s>) = 0.0001
# P(Ferruzzi | <s>) = 0.0001
# P(Edelman | <s>) = 0.0001
# P(Hoechst | <s>) = 0.0001
# P(Tomorrow | <s>) = 0.0001
# P(GOLDEN | <s>) = 0.0001
# P(GHANA | <s>) = 0.0001
# P(Cominco | <s>) = 0.0001
# P(Day | <s>) = 0.0001
# P(DAYTON | <s>) = 0.0001
# P(Short | <s>) = 0.0001
# P(Moscow | <s>) = 0.0001
# P(Operators | <s>) = 0.0001
# P(JOHNSON | <s>) = 0.0001
# P(Concern | <s>) = 0.0001
# P(Revenue | <s>) = 0.0001
# P(COLONIAL | <s>) = 0.0001
# P(GLOBAL | <s>) = 0.0001
# P(Economic | <s>) = 0.0001
# P(Data | <s>) = 0.0001
# P(HUMANA | <s>) = 0.0001
# P(Nearly | <s>) = 0.0001
# P(Henry | <s>) = 0.0001
# P(Brennan | <s>) = 0.0001
# P(Sugar | <s>) = 0.0001
# P(MAGMA | <s>) = 0.0001
# P(Soybeans | <s>) = 0.0001
# P(Rice | <s>) = 0.0001
# P(Citing | <s>) = 0.0001
# P(Chinese | <s>) = 0.0001
# P(Customs | <s>) = 0.0001
# P(CURRENCY | <s>) = 0.0001
# P(What | <s>) = 0.0001
# P(Bangemann | <s>) = 0.0001
# P(Nor | <s>) = 0.0001
# P(PORTUGUESE | <s>) = 0.0001
# P(Investment | <s>) = 0.0001
# P(IRVING | <s>) = 0.0001
# P(SCOTT | <s>) = 0.0001
# P(PEOPLES | <s>) = 0.0001
# P(REVLON | <s>) = 0.0001
# P(Revlon | <s>) = 0.0001
# P(Concerning | <s>) = 0.0001
# P(ATLANTIC | <s>) = 0.0001
# P(PERSONAL | <s>) = 0.0001
# P(Jones | <s>) = 0.0001
# P(NOVA | <s>) = 0.0001
# P(FLORIDA | <s>) = 0.0001
# P("( | <s>) = 0.0001
# P(Congress | <s>) = 0.0001
# P(Thus | <s>) = 0.0001
# P(COMINCO | <s>) = 0.0001
# P(Spectra | <s>) = 0.0001
# P(Entertainment | <s>) = 0.0001
# P(ADVANCED | <s>) = 0.0001
# P(Silver | <s>) = 0.0001
# P(BILZERIAN | <s>) = 0.0001
# P(Waste | <s>) = 0.0001
# P(Repayments | <s>) = 0.0001
# P(SANTOS | <s>) = 0.0001
# P(Tehran | <s>) = 0.0001
# P(Exporters | <s>) = 0.0001
# P(Overnight | <s>) = 0.0001
# P(SHULTZ | <s>) = 0.0001
# P(Shultz | <s>) = 0.0001
# P(Thomas | <s>) = 0.0001
# P(Overseas | <s>) = 0.0001
# P(Higher | <s>) = 0.0001
# P(News | <s>) = 0.0001
# P(IMPERIAL | <s>) = 0.0001
# P(SOUTHLAND | <s>) = 0.0001
# P(PAN | <s>) = 0.0001
# P(APPLIED | <s>) = 0.0001
# P(Mining | <s>) = 0.0001
# P(ROCHESTER | <s>) = 0.0001
# P(SENATOR | <s>) = 0.0001
# P(Estimates | <s>) = 0.0001
# P(Rain | <s>) = 0.0001
# P(Malaysian | <s>) = 0.0001
# P(Housing | <s>) = 0.0001
# P(Additional | <s>) = 0.0001
# P(INTER | <s>) = 0.0001
# P(UTILICORP | <s>) = 0.0001
# P(Depending | <s>) = 0.0001
# P(Shipping | <s>) = 0.0001
# P(20 | <s>) = 0.0001
# P(CITICORP | <s>) = 0.0001
# P(Subroto | <s>) = 0.0001
# P(IRANIAN | <s>) = 0.0001
# P(BALLADUR | <s>) = 0.0001
# P(TRANSAMERICA | <s>) = 0.0001
# P(Ambassador | <s>) = 0.0001
# P(Defense | <s>) = 0.0001
# P(Around | <s>) = 0.0001
# P(You | <s>) = 0.0001
# P(Metropolitan | <s>) = 0.0001
# P(SENATE | <s>) = 0.0001
# P(MEDIA | <s>) = 0.0001
# P(CTS | <s>) = 0.0001
# P(CCR | <s>) = 0.0001
# P(Initially | <s>) = 0.0001
# P(St | <s>) = 0.0001
# P(STERLING | <s>) = 0.0001
# P(STUDY | <s>) = 0.0001
# P(Talyzin | <s>) = 0.0001
# P(CABLE | <s>) = 0.0001
# P(Telecom | <s>) = 0.0001
# P(Pillsbury | <s>) = 0.0001
# P(Farm | <s>) = 0.0001
# P(Tenneco | <s>) = 0.0001
# P(Alcan | <s>) = 0.0001
# P(Progressive | <s>) = 0.0001
# P(Rainbow | <s>) = 0.0001
# P(Thai | <s>) = 0.0001
# P(Papandreou | <s>) = 0.0001
# P(Reserves | <s>) = 0.0001
# P(Board | <s>) = 0.0001
# P(Mannesmann | <s>) = 0.0001
# P(Deposits | <s>) = 0.0001
# P(Main | <s>) = 0.0001
# P(FEBRUARY | <s>) = 0.0001
# P(Nevertheless | <s>) = 0.0001
# P(UNICORP | <s>) = 0.0001
# P(Arango | <s>) = 0.0001
# P(Tender | <s>) = 0.0001
# P(HOUSTON | <s>) = 0.0001
# P(Rates | <s>) = 0.0001
# P(Liquidity | <s>) = 0.0001
# P(Guinness | <s>) = 0.0001
# P(Harper | <s>) = 0.0001
# P(COOPER | <s>) = 0.0001
# P(Philip | <s>) = 0.0001
# P(Resources | <s>) = 0.0001
# P(PIEDMONT | <s>) = 0.0001
# P(Pickens | <s>) = 0.0001
# P(Keating | <s>) = 0.0001
# P(Tax | <s>) = 0.0001
# P(ATT | <s>) = 0.0001
# P(SHV | <s>) = 0.0001
# P(BARCLAYS | <s>) = 0.0001
# P(Peru | <s>) = 0.0001
# P(Dole | <s>) = 0.0001
# P(Holden | <s>) = 0.0001
# P(VARITY | <s>) = 0.0001
# P(Coastal | <s>) = 0.0001
# P(Pinola | <s>) = 0.0001
# P(Like | <s>) = 0.0001
# P(BOND | <s>) = 0.0001
# P(Agricultural | <s>) = 0.0001
# P(Apart | <s>) = 0.0001
# P(JARDINE | <s>) = 0.0001
# P(BELL | <s>) = 0.0001
# P(CALIFORNIA | <s>) = 0.0001
# P(WTC | <s>) = 0.0001
# P(Assuming | <s>) = 0.0001
# P(Vice | <s>) = 0.0001
# P(Greece | <s>) = 0.0001
# P(Siemens | <s>) = 0.0001
# P(INDUSTRIAL | <s>) = 0.0001
# P(Kenneth | <s>) = 0.0001
# P(GE | <s>) = 0.0001
# P(IBM | <s>) = 0.0001
# P(Record | <s>) = 0.0001
# P(STEWART | <s>) = 0.0001
# P(RECENT | <s>) = 0.0001
# P(he | <s>) = 0.0001
# P(THAILAND | <s>) = 0.0001
# P(FAO | <s>) = 0.0001
# P(Merchant | <s>) = 0.0001
# P(REICHHOLD | <s>) = 0.0001
# P(Reichhold | <s>) = 0.0001
# P(LVI | <s>) = 0.0001
# P(T | <s>) = 0.0001
# P(Diamond | <s>) = 0.0001
# P(Income | <s>) = 0.0001
# P(Due | <s>) = 0.0001
# P(John | <s>) = 0.0001
# P(MONSANTO | <s>) = 0.0001
# P(Penney | <s>) = 0.0001
# P(Hudson | <s>) = 0.0001
# P(Should | <s>) = 0.0001
# P(CITY | <s>) = 0.0001
# P(Y | <s>) = 0.0001
# P(Shamrock | <s>) = 0.0001
# P(Lichtblau | <s>) = 0.0001
# P(Level | <s>) = 0.0001
# P(Mobil | <s>) = 0.0001
# P(Siew | <s>) = 0.0001
# P(Howard | <s>) = 0.0001
# P(SAMA | <s>) = 0.0001
# P(UAE | <s>) = 0.0001
# P(Het | <s>) = 0.0001
# P(Istat | <s>) = 0.0001
# P(Darman | <s>) = 0.0001
# P(CRAZY | <s>) = 0.0001
# P(Crazy | <s>) = 0.0001
# P(Bentsen | <s>) = 0.0001
# P(Pentland | <s>) = 0.0001
# P(ALLWASTE | <s>) = 0.0001
# P(MARK | <s>) = 0.0001
# P(Includes | <s>) = 0.0001
# P(Charles | <s>) = 0.0001
# P(WELLS | <s>) = 0.0001
# P(INT | <s>) = 0.0001
# P(Kato | <s>) = 0.0001
# P(MARTIN | <s>) = 0.0001
# P(Ortner | <s>) = 0.0001
# P(Westpac | <s>) = 0.0001
# P(Romero | <s>) = 0.0001
# P(Pay | <s>) = 0.0001
# P(Campeau | <s>) = 0.0001
# P(LITTLE | <s>) = 0.0001
# P(ALCOA | <s>) = 0.0001
# P(CONT | <s>) = 0.0001
# P(MALAYSIAN | <s>) = 0.0001
# P(Faced | <s>) = 0.0001
# P(Sarney | <s>) = 0.0001
# P(Phelps | <s>) = 0.0001
# P(WICKES | <s>) = 0.0001
# P(FREEDOM | <s>) = 0.0001
# P(LIBERTY | <s>) = 0.0001
# P(BECOR | <s>) = 0.0001
# P(PETRO | <s>) = 0.0001
# P(Unocal | <s>) = 0.0001
# P(ZCCM | <s>) = 0.0001
# P(Heinz | <s>) = 0.0001
# P(Base | <s>) = 0.0001
# P(Greyhound | <s>) = 0.0001
# P(Licht | <s>) = 0.0001
# P(Notes | <s>) = 0.0001
# P(HK | <s>) = 0.0001
# P(Egypt | <s>) = 0.0001
# P(Danish | <s>) = 0.0001
# P(BSN | <s>) = 0.0001
# P(Outokumpu | <s>) = 0.0001
# P(LAIDLAW | <s>) = 0.0001
# P(Consequently | <s>) = 0.0001
# P(Kellogg | <s>) = 0.0001
# P(Pakistan | <s>) = 0.0001
# P(D | <s>) = 0.0001
# P(Fears | <s>) = 0.0001
# P(Multi | <s>) = 0.0001
# P(Phillips | <s>) = 0.0001
# P(PUBLIC | <s>) = 0.0001
# P(OWENS | <s>) = 0.0001
# P(QUAKER | <s>) = 0.0001
# P(NL | <s>) = 0.0001
# P(Regarding | <s>) = 0.0001
# P(Telephone | <s>) = 0.0001
# P(Heyman | <s>) = 0.0001
# P(North | <s>) = 0.0001
# P(PILLSBURY | <s>) = 0.0001
# P(MONEY | <s>) = 0.0001
# P(Roderick | <s>) = 0.0001
# P(NY | <s>) = 0.0001
# P(Management | <s>) = 0.0001
# P(ZIMBABWE | <s>) = 0.0001
# P(Hanson | <s>) = 0.0001
# P(LOWER | <s>) = 0.0001
# P(Hungary | <s>) = 0.0001
# P(SOUTHWESTERN | <s>) = 0.0001
# P(CONAGRA | <s>) = 0.0001
# P(Effective | <s>) = 0.0001
# P(Legal | <s>) = 0.0001
# P(McLean | <s>) = 0.0001
# P(Proposed | <s>) = 0.0001
# P(Mulford | <s>) = 0.0001
# P(Prospects | <s>) = 0.0001
# P(Adsteam | <s>) = 0.0001
# P(Gardini | <s>) = 0.0001
# P(TRADERS | <s>) = 0.0001
# P(Excludes | <s>) = 0.0001
# P(EMERY | <s>) = 0.0001
# P(BOLIDEN | <s>) = 0.0001
# P(Next | <s>) = 0.0001
# P(Allis | <s>) = 0.0001
# P(VMS | <s>) = 0.0001
# P(Gardner | <s>) = 0.0001
# P(Reports | <s>) = 0.0001
# P(Herrhausen | <s>) = 0.0001
# P(Not | <s>) = 0.0001
# P(Unless | <s>) = 0.0001
# P(CBT | <s>) = 0.0001
# P(Public | <s>) = 0.0001
# P(Bigelow | <s>) = 0.0001
# P(IEA | <s>) = 0.0001
# P(Qintex | <s>) = 0.0001
# P(Gaviria | <s>) = 0.0001
# P(Channon | <s>) = 0.0001
# P(Port | <s>) = 0.0001
# P(LUCKY | <s>) = 0.0001
# P(Southwest | <s>) = 0.0001
# P(Petro | <s>) = 0.0001
# P(BALLY | <s>) = 0.0001
# P(King | <s>) = 0.0001
# P(Preussag | <s>) = 0.0001
# P(JIM | <s>) = 0.0001
# P(Iowa | <s>) = 0.0001
# P(ECHLIN | <s>) = 0.0001
# P(FAIRCHILD | <s>) = 0.0001
# P(Ina | <s>) = 0.0001
# P(Levon | <s>) = 0.0001
# P(Fendt | <s>) = 0.0001
# P(Reed | <s>) = 0.0001
# P(ROSPATCH | <s>) = 0.0001
# P(Comalco | <s>) = 0.0001
# P(IWC | <s>) = 0.0001
# P(Equatorial | <s>) = 0.0001
# P(Annual | <s>) = 0.0001
# P(Industries | <s>) = 0.0001
# P(Monier | <s>) = 0.0001
# P(Bell | <s>) = 0.0001
# P(Mills | <s>) = 0.0001
# P(Initial | <s>) = 0.0001
# P(TOP | <s>) = 0.0001
# P(Quarter | <s>) = 0.0001
# P(DOMINION | <s>) = 0.0001
# P(RAYTHEON | <s>) = 0.0001
# P(Dominion | <s>) = 0.0001
# P(HONDURAS | <s>) = 0.0001
# P(HOECHST | <s>) = 0.0001
# P(LORD | <s>) = 0.0001
# P(Heineken | <s>) = 0.0001
# P(Wallin | <s>) = 0.0001
# P(Fitzwater | <s>) = 0.0001
# P(COPPER | <s>) = 0.0001
# P(Teck | <s>) = 0.0001
# P(NAT | <s>) = 0.0001
# P(Similarly | <s>) = 0.0001
# P(GATEWAY | <s>) = 0.0001
# P(Statistics | <s>) = 0.0001
# P(Consumption | <s>) = 0.0001
# P(Pretax | <s>) = 0.0001
# P(Eishiro | <s>) = 0.0001
# P(Saito | <s>) = 0.0001
# P(Part | <s>) = 0.0001
# P(Previous | <s>) = 0.0001
# P(Lex | <s>) = 0.0001
# P(Shortly | <s>) = 0.0001
# P(CLEVITE | <s>) = 0.0001
# P(PHILIP | <s>) = 0.0001
# P(Sunflowerseed | <s>) = 0.0001
# P(Bonn | <s>) = 0.0001
# P(SPANISH | <s>) = 0.0001
# P(Taking | <s>) = 0.0001
# P(Barley | <s>) = 0.0001
# P(. | <s>) = 0.0001
# P(RJR | <s>) = 0.0001
# P(ZAYRE | <s>) = 0.0001
# P(AMOSKEAG | <s>) = 0.0001
# P(FINAL | <s>) = 0.0001
# P(Normally | <s>) = 0.0001
# P(Loan | <s>) = 0.0001
# P(Tenders | <s>) = 0.0001
# P(Use | <s>) = 0.0001
# P(Selling | <s>) = 0.0001
# P(NSPA | <s>) = 0.0001
# P(Fundamental | <s>) = 0.0001
# P(BANKS | <s>) = 0.0001
# P(Sri | <s>) = 0.0001
# P(HOSPITAL | <s>) = 0.0001
# P(Live | <s>) = 0.0001
# P(MOORE | <s>) = 0.0001
# P(PARTNERSHIP | <s>) = 0.0001
# P(Giordano | <s>) = 0.0001
# P(Corporate | <s>) = 0.0001
# P(HUNGARY | <s>) = 0.0001
# P(MTI | <s>) = 0.0001
# P(YUGOSLAV | <s>) = 0.0001
# P(Payments | <s>) = 0.0001
# P(MORGAN | <s>) = 0.0001
# P(Along | <s>) = 0.0001
# P(LME | <s>) = 0.0001
# P(FAMILY | <s>) = 0.0001
# P(Boston | <s>) = 0.0001
# P(COOPERVISION | <s>) = 0.0001
# P(Foster | <s>) = 0.0001
# P(LASER | <s>) = 0.0001
# P(Triton | <s>) = 0.0001
# P(MacAndrews | <s>) = 0.0001
# P(Mercer | <s>) = 0.0001
# P(Aristech | <s>) = 0.0001
# P(Contract | <s>) = 0.0001
# P(Lewis | <s>) = 0.0001
# P(CHAMPION | <s>) = 0.0001
# P(HONEYWELL | <s>) = 0.0001
# P(IN | <s>) = 0.0001
# P(DEL | <s>) = 0.0001
# P(NEWMONT | <s>) = 0.0001
# P(INTERCO | <s>) = 0.0001
# P(VALLEY | <s>) = 0.0001
# P(Complaints | <s>) = 0.0001
# P(Chicago | <s>) = 0.0001
# P(CALNY | <s>) = 0.0001
# P(Plans | <s>) = 0.0001
# P(COMMUNICATIONS | <s>) = 0.0001
# P(HORIZON | <s>) = 0.0001
# P(Lead | <s>) = 0.0001
# P(City | <s>) = 0.0001
# P(Allegis | <s>) = 0.0001
# P(BOEING | <s>) = 0.0001
# P(ONIC | <s>) = 0.0001
# P(Petroleum | <s>) = 0.0001
# P(Sun | <s>) = 0.0001
# P(TIN | <s>) = 0.0001
# P(Scott | <s>) = 0.0001
# P(USPCI | <s>) = 0.0001
# P(EDELMAN | <s>) = 0.0001
# P(BURLINGTON | <s>) = 0.0001
# P(Fernandez | <s>) = 0.0001
# P(GDP | <s>) = 0.0001
# P(JONES | <s>) = 0.0001
# P(BALL | <s>) = 0.0001
# P(KAUFMAN | <s>) = 0.0001
# P(Sims | <s>) = 0.0001
# P(ASAMERA | <s>) = 0.0001
# P(Copper | <s>) = 0.0001
# P(MEXICO | <s>) = 0.0001
# P(Hard | <s>) = 0.0001
# P(Div | <s>) = 0.0001
# P(THOMSON | <s>) = 0.0001
# P(JWT | <s>) = 0.0001
# P(Affandi | <s>) = 0.0001
# P(PERMIAN | <s>) = 0.0001
# P(Opening | <s>) = 0.0001
# P(DUPONT | <s>) = 0.0001
# P(ZAMBIAN | <s>) = 0.0001
# P(Rumors | <s>) = 0.0001
# P(Gas | <s>) = 0.0001
# P(Otherwise | <s>) = 0.0001
# P(CARTER | <s>) = 0.0001
# P(Belgium | <s>) = 0.0001
# P(Becor | <s>) = 0.0001
# P(GREYHOUND | <s>) = 0.0001
# P(COLD | <s>) = 0.0001
# P(Weather | <s>) = 0.0001
# P(METRO | <s>) = 0.0001
# P(Horizon | <s>) = 0.0001
# P(Lim | <s>) = 0.0001
# P(TEKTRONIX | <s>) = 0.0001
# P(Ali | <s>) = 0.0001
# P(IVORY | <s>) = 0.0001
# P(Staley | <s>) = 0.0001
# P(Warships | <s>) = 0.0001
# P(Flag | <s>) = 0.0001
# P(GABELLI | <s>) = 0.0001
# P(MORRISON | <s>) = 0.0001
# P(WAL | <s>) = 0.0001
# P(ATTACK | <s>) = 0.0001
# P(Iranian | <s>) = 0.0001
# P(SCHLUMBERGER | <s>) = 0.0001
# P(AVON | <s>) = 0.0001
# P(Equity | <s>) = 0.0001
# P(LOUISIANA | <s>) = 0.0001
# P(BRISTOL | <s>) = 0.0001
# P(COCA | <s>) = 0.0001
# P(METROPOLITAN | <s>) = 0.0001
# P(JACOBS | <s>) = 0.0001
# P(MERCANTILE | <s>) = 0.0001
# P(Lord | <s>) = 0.0001
# P(GUINNESS | <s>) = 0.0001
# P(LINCOLN | <s>) = 0.0001
# P(Per | <s>) = 0.0001
# P(19 | <s>) = 0.0001
# P(BRITAIN | <s>) = 0.0001
# P(Referring | <s>) = 0.0001
# P(Pending | <s>) = 0.0001
# P(Henley | <s>) = 0.0001
# P(December | <s>) = 0.0001
# P(Individual | <s>) = 0.0001
# P(AIR | <s>) = 0.0001
# P(Boliden | <s>) = 0.0001
# P(SOUTHWEST | <s>) = 0.0001
# P(IDC | <s>) = 0.0001
# P(MIM | <s>) = 0.0001
# P(DEUTSCHE | <s>) = 0.0001
# P(Buyers | <s>) = 0.0001
# P(Import | <s>) = 0.0001
# P(Gould | <s>) = 0.0001
# P(MINSTAR | <s>) = 0.0001
# P(Combustion | <s>) = 0.0001
# P(FERRUZZI | <s>) = 0.0001
# P(Goldman | <s>) = 0.0001
# P(McIntyre | <s>) = 0.0001
# P(Nonetheless | <s>) = 0.0001
# P(CTC | <s>) = 0.0001
# P(Third | <s>) = 0.0001
# P(SUGAR | <s>) = 0.0001
# P(Cocoa | <s>) = 0.0001
# P(DEALERS | <s>) = 0.0001
# P(GREECE | <s>) = 0.0001
# P(Purchases | <s>) = 0.0001
# P(Changes | <s>) = 0.0001
# P(CORNING | <s>) = 0.0001
# P(Credit | <s>) = 0.0001
# P(Ivory | <s>) = 0.0001
# P(NEWS | <s>) = 0.0001
# P(OPPENHEIMER | <s>) = 0.0001
# P(Dow | <s>) = 0.0001
# P(Refinery | <s>) = 0.0001
# P(Together | <s>) = 0.0001
# P(Using | <s>) = 0.0001
# P(COMMERCIAL | <s>) = 0.0001
# P(Hutchison | <s>) = 0.0001
# P(Negotiators | <s>) = 0.0001
# P(Dieter | <s>) = 0.0001
# P(REXNORD | <s>) = 0.0001
# P(Producer | <s>) = 0.0001
# P(Continued | <s>) = 0.0001
# P(Keycorp | <s>) = 0.0001
# P(BUTLER | <s>) = 0.0001
# P(Greenmail | <s>) = 0.0001
# P(BENEFICIAL | <s>) = 0.0001
# P(MCO | <s>) = 0.0001
# P(Friday | <s>) = 0.0001
# P(Seipp | <s>) = 0.0001
# P(Sudan | <s>) = 0.0001
# P(DELTA | <s>) = 0.0001
# P(CHINESE | <s>) = 0.0001
# P(Snow | <s>) = 0.0001
# P(Indeed | <s>) = 0.0001
# P(Lloyds | <s>) = 0.0001
# P(Loh | <s>) = 0.0001
# P(Sanwa | <s>) = 0.0001
# P(Watanabe | <s>) = 0.0001
# P(KEY | <s>) = 0.0001
# P(GPU | <s>) = 0.0001
# P(Bids | <s>) = 0.0001
# P(Eyskens | <s>) = 0.0001
# P(Aziz | <s>) = 0.0001
# P(Supermarkets | <s>) = 0.0001
# P(FCS | <s>) = 0.0001
# P(Bayou | <s>) = 0.0001
# P(KANEB | <s>) = 0.0001
# P(WHITTAKER | <s>) = 0.0001
# P(Mueller | <s>) = 0.0001
# P(Dresdner | <s>) = 0.0001
# P(7 | <s>) = 0.0001
# P(Rainfall | <s>) = 0.0001
# P(COMDATA | <s>) = 0.0001
# P(Kidder | <s>) = 0.0001
# P(Dynamics | <s>) = 0.0001
# P(Beet | <s>) = 0.0001
# P(Yet | <s>) = 0.0001
# P(Lending | <s>) = 0.0001
# P(Opec | <s>) = 0.0001
# P(EASTMAN | <s>) = 0.0001
# P(Kodak | <s>) = 0.0001
# P(COMBINED | <s>) = 0.0001
# P(ASCS | <s>) = 0.0001
# P(SIEMENS | <s>) = 0.0001
# P(PATRICK | <s>) = 0.0001
# P(Mathematical | <s>) = 0.0001
# P(CEASARS | <s>) = 0.0001
# P(Ultramar | <s>) = 0.0001
# P(Li | <s>) = 0.0001
# P(Fekete | <s>) = 0.0001
# P(Conference | <s>) = 0.0001
# P(Building | <s>) = 0.0001
# P(Lee | <s>) = 0.0001
# P(GELCO | <s>) = 0.0001
# P(Bally | <s>) = 0.0001
# P(ENDOTRONICS | <s>) = 0.0001
# P(Endotronics | <s>) = 0.0001
# P(CANBRA | <s>) = 0.0001
# P(AFFILIATED | <s>) = 0.0001
# P(DNA | <s>) = 0.0001
# P(CATHAY | <s>) = 0.0001
# P(Cathay | <s>) = 0.0001
# P(Norstar | <s>) = 0.0001
# P(HRE | <s>) = 0.0001
# P(Al | <s>) = 0.0001
# P(Lear | <s>) = 0.0001
# P(Habbel | <s>) = 0.0001
# P(Brooks | <s>) = 0.0001
# P(Wagner | <s>) = 0.0001
# P(Champion | <s>) = 0.0001
# P(Fairfax | <s>) = 0.0001
# P(FOOTE | <s>) = 0.0001
# P(NESTLE | <s>) = 0.0001
# P(Nestle | <s>) = 0.0001
# P(COOK | <s>) = 0.0001
# P(Cook | <s>) = 0.0001
# P(Charter | <s>) = 0.0001
# P(LILCO | <s>) = 0.0001
# P(Hata | <s>) = 0.0001
# P(Swire | <s>) = 0.0001
# P(Foote | <s>) = 0.0001
# P(HEALTHMATE | <s>) = 0.0001
# P(ASIAN | <s>) = 0.0001
# P(Products | <s>) = 0.0001
# P(SUMITOMO | <s>) = 0.0001
# P(Suppliers | <s>) = 0.0001
# P(Diaz | <s>) = 0.0001
# P(Offshore | <s>) = 0.0001
# P(Cabinet | <s>) = 0.0001
# P(Palm | <s>) = 0.0001
# P(Elsewhere | <s>) = 0.0001
# P(RUBBERMAID | <s>) = 0.0001
# P(Proxmire | <s>) = 0.0001
# P(Rather | <s>) = 0.0001
# P(Conditions | <s>) = 0.0001
# P(MAYFAIR | <s>) = 0.0001
# P(Italian | <s>) = 0.0001
# P(PARIS | <s>) = 0.0001
# P(MONTEDISON | <s>) = 0.0001
# P(TRUMP | <s>) = 0.0001
# P(STERIVET | <s>) = 0.0001
# P(WALGREEN | <s>) = 0.0001
# P(Iraqi | <s>) = 0.0001
# P(Donald | <s>) = 0.0001
# P(IRNA | <s>) = 0.0001
# P(MEXICAN | <s>) = 0.0001
# P(SOUTHEAST | <s>) = 0.0001
# P(PARKER | <s>) = 0.0001
# P(Subscriptions | <s>) = 0.0001
# P(Large | <s>) = 0.0001
# P(YEN | <s>) = 0.0001
# P(CB | <s>) = 0.0001
# P(TODD | <s>) = 0.0001
# P(Todd | <s>) = 0.0001
# P(RPT | <s>) = 0.0001
# P(SAO | <s>) = 0.0001
# P(ANCHOR | <s>) = 0.0001
# P(ABBOTT | <s>) = 0.0001
# P(Harris | <s>) = 0.0001
# P(Research | <s>) = 0.0001
# P(Unlike | <s>) = 0.0001
# P(TIME | <s>) = 0.0001
# P(COMMUNITY | <s>) = 0.0001
# P(Zimbabwe | <s>) = 0.0001
# P(SEA | <s>) = 0.0001
# P(STOP | <s>) = 0.0001
# P(CORN | <s>) = 0.0001
# P(RICE | <s>) = 0.0001
# P(Oats | <s>) = 0.0001
# P(AUDIO | <s>) = 0.0001
# P(FLUOROCARBON | <s>) = 0.0001
# P(FROST | <s>) = 0.0001
# P(CENTEL | <s>) = 0.0001
# P(ADAMS | <s>) = 0.0001
# P(NEWHALL | <s>) = 0.0001
# P(Louisiana | <s>) = 0.0001
# P(Borrowings | <s>) = 0.0001
# P(Brent | <s>) = 0.0001
# P(Goodrich | <s>) = 0.0001
# P(CHILEAN | <s>) = 0.0001
# P(Stephen | <s>) = 0.0001
# P(UGANDA | <s>) = 0.0001
# P(Cuts | <s>) = 0.0001
# P(Pennzoil | <s>) = 0.0001
# P(Personal | <s>) = 0.0001
# P(BLUE | <s>) = 0.0001
# P(Companies | <s>) = 0.0001
# P(Thirty | <s>) = 0.0001
# P(Royex | <s>) = 0.0001
# P(Home | <s>) = 0.0001
# P(GLATFELTER | <s>) = 0.0001
# P(Sight | <s>) = 0.0001
# P(Goodyear | <s>) = 0.0001
# P(Glatfelter | <s>) = 0.0001
# P(BOSTON | <s>) = 0.0001
# P(PARK | <s>) = 0.0001
# P(DILLARD | <s>) = 0.0001
# P(Period | <s>) = 0.0001
# P(Kahn | <s>) = 0.0001
# P(SWIFT | <s>) = 0.0001
# P(Buitoni | <s>) = 0.0001
# P(OAK | <s>) = 0.0001
# P(Irving | <s>) = 0.0001
# P(Drexel | <s>) = 0.0001
# P(Atlantic | <s>) = 0.0001
# P(KDI | <s>) = 0.0001
# P(Ericsson | <s>) = 0.0001
# P(BROOKLYN | <s>) = 0.0001
# P(KUWAITI | <s>) = 0.0001
# P(Manufacturers | <s>) = 0.0001
# P(Refined | <s>) = 0.0001
# P(KRAFT | <s>) = 0.0001
# P(CONVERGENT | <s>) = 0.0001
# P(Direct | <s>) = 0.0001
# P(INSEE | <s>) = 0.0001
# P(Ten | <s>) = 0.0001
# P(Ford | <s>) = 0.0001
# P(KENTUCKY | <s>) = 0.0001
# P(Discount | <s>) = 0.0001
# P(Grade | <s>) = 0.0001
# P(Eighty | <s>) = 0.0001
# P(lead | <s>) = 0.0001
# P(SPECTRA | <s>) = 0.0001
# P(ARGOSystems | <s>) = 0.0001
# P(Aramco | <s>) = 0.0001
# P(Video | <s>) = 0.0001
# P(PAY | <s>) = 0.0001
# P(Borden | <s>) = 0.0001
# P(Humana | <s>) = 0.0001
# P(Worldwide | <s>) = 0.0001
# P(SAFETY | <s>) = 0.0001
# P(COMEX | <s>) = 0.0001
# P(Computerland | <s>) = 0.0001
# P(WANTS | <s>) = 0.0001
# P(Free | <s>) = 0.0001
# P(Prudential | <s>) = 0.0001
# P(ROYEX | <s>) = 0.0001
# P(DRESSER | <s>) = 0.0001
# P(ATCOR | <s>) = 0.0001
# P(Samjens | <s>) = 0.0001
# P(Heavy | <s>) = 0.0001
# P(Agip | <s>) = 0.0001
# P(Du | <s>) = 0.0001
# P(Pointing | <s>) = 0.0001
# P(ACME | <s>) = 0.0001
# P(Hodel | <s>) = 0.0001
# P(Sweden | <s>) = 0.0001
# P(CENTURY | <s>) = 0.0001
# P(Heating | <s>) = 0.0001
# P(Monday | <s>) = 0.0001
# P(Lynch | <s>) = 0.0001
# P(Daily | <s>) = 0.0001
# P(PHELPS | <s>) = 0.0001
# P(Durham | <s>) = 0.0001
# P(Glenn | <s>) = 0.0001
# P(COLOMBIAN | <s>) = 0.0001
# P(Rapeseed | <s>) = 0.0001
# P(Partially | <s>) = 0.0001
# P(Wholesale | <s>) = 0.0001
# P(Dairy | <s>) = 0.0001
# P(Preliminary | <s>) = 0.0001
# P(GNP | <s>) = 0.0001
# P(Toshiba | <s>) = 0.0001
# P(Claims | <s>) = 0.0001
# P(Unit | <s>) = 0.0001
# P(William | <s>) = 0.0001
# P(GILLETTE | <s>) = 0.0001
# P(Liberty | <s>) = 0.0001
# P(TULTEX | <s>) = 0.0001
# P(Convertible | <s>) = 0.0001
# P(Pan | <s>) = 0.0001
# P(Rank | <s>) = 0.0001
# P(Conoco | <s>) = 0.0001
# P(TANZANIA | <s>) = 0.0001
# P(Brooklyn | <s>) = 0.0001
# P(Transco | <s>) = 0.0001
# P(Belgian | <s>) = 0.0001
# P(Squibb | <s>) = 0.0001
# P(Fildes | <s>) = 0.0001
# P(MITSUI | <s>) = 0.0001
# P(Sainsbury | <s>) = 0.0001
# P(Few | <s>) = 0.0001
# P(Secretary | <s>) = 0.0001
# P(Calls | <s>) = 0.0001
# P(Press | <s>) = 0.0001
# P(Temperatures | <s>) = 0.0001
# P(FORTUNE | <s>) = 0.0001
# P(IRWIN | <s>) = 0.0001
# P(LATIN | <s>) = 0.0001
# P(Rodriguez | <s>) = 0.0001
# P(Rosenbaum | <s>) = 0.0001
# P(Shad | <s>) = 0.0001
# P(TENNECO | <s>) = 0.0001
# P(September | <s>) = 0.0001
# P(Police | <s>) = 0.0001
# P(Refiners | <s>) = 0.0001
# P(Qatar | <s>) = 0.0001
# P(Willis | <s>) = 0.0001
# P(Andriessen | <s>) = 0.0001
# P(16 | <s>) = 0.0001
# P(Protectionism | <s>) = 0.0001
# P(HOVNANIAN | <s>) = 0.0001
# P(Wright | <s>) = 0.0001
# P(Seton | <s>) = 0.0001
# P(PRECISION | <s>) = 0.0001
# P(Our | <s>) = 0.0001
# P(Ryan | <s>) = 0.0001
# P(JUSTICE | <s>) = 0.0001
# P(Exchange | <s>) = 0.0001
# P(CORBY | <s>) = 0.0001
# P(Attacks | <s>) = 0.0001
# P(Permits | <s>) = 0.0001
# P(Single | <s>) = 0.0001
# P(TRIBUNE | <s>) = 0.0001
# P(DOMTAR | <s>) = 0.0001
# P(ALGERIA | <s>) = 0.0001
# P(BETHLEHEM | <s>) = 0.0001
# P(COLEMAN | <s>) = 0.0001
# P(DONALD | <s>) = 0.0001
# P(ASA | <s>) = 0.0001
# P(Argentina | <s>) = 0.0001
# P(CITIZENS | <s>) = 0.0001
# P(SCIENCE | <s>) = 0.0001
# P(NETWORK | <s>) = 0.0001
# P(Food | <s>) = 0.0001
# P(REGENCY | <s>) = 0.0001
# P(TELEX | <s>) = 0.0001
# P(BONN | <s>) = 0.0001
# P(PEPSICO | <s>) = 0.0001
# P(SAFEGUARD | <s>) = 0.0001
# P(NORTHEAST | <s>) = 0.0001
# P(BCI | <s>) = 0.0001
# P(AMCAST | <s>) = 0.0001
# P(SHAMROCK | <s>) = 0.0001
# P(Harvesting | <s>) = 0.0001
# P(MIDDLE | <s>) = 0.0001
# P(OREGON | <s>) = 0.0001
# P(Revs | <s>) = 0.0001
# P(GEORGIA | <s>) = 0.0001
# P(Naval | <s>) = 0.0001
# P(UNITS | <s>) = 0.0001
# P(INDIAN | <s>) = 0.0001
# P(Political | <s>) = 0.0001
# P(Association | <s>) = 0.0001
# P(RUBBER | <s>) = 0.0001
# P(Hofmeister | <s>) = 0.0001
# P(GOULD | <s>) = 0.0001
# P(REPORT | <s>) = 0.0001
# P(OLD | <s>) = 0.0001
# P(Cardenas | <s>) = 0.0001
# P(COMBUSTION | <s>) = 0.0001
# P(Jordan | <s>) = 0.0001
# P(FORMER | <s>) = 0.0001
# P(None | <s>) = 0.0001
# P(Martin | <s>) = 0.0001
# P(KENYAN | <s>) = 0.0001
# P(FOREIGN | <s>) = 0.0001
# P(Countertrade | <s>) = 0.0001
# P(Transfer | <s>) = 0.0001
# P(Taylor | <s>) = 0.0001
# P(MITSUBISHI | <s>) = 0.0001
# P(Dlr | <s>) = 0.0001
# P(Investments | <s>) = 0.0001
# P(Managing | <s>) = 0.0001
# P(Spethmann | <s>) = 0.0001
# P(Greek | <s>) = 0.0001
# P(Up | <s>) = 0.0001
# P(Privately | <s>) = 0.0001
# P(LSB | <s>) = 0.0001
# P(Galactic | <s>) = 0.0001
# P(DROUGHT | <s>) = 0.0001
# P(Discussions | <s>) = 0.0001
# P(OFFICIAL | <s>) = 0.0001
# P(Garcia | <s>) = 0.0001
# P(BTR | <s>) = 0.0001
# P(Months | <s>) = 0.0001
# P(Tam | <s>) = 0.0001
# P(TESCO | <s>) = 0.0001
# P(LAC | <s>) = 0.0001
# P(PHILADELPHIA | <s>) = 0.0001
# P(MANNESMANN | <s>) = 0.0001
# P(CLABIR | <s>) = 0.0001
# P(Defence | <s>) = 0.0001
# P(SCIENTIFIC | <s>) = 0.0001
# P(INTELLIGENT | <s>) = 0.0001
# P(Purchase | <s>) = 0.0001
# P(Questioned | <s>) = 0.0001
# P(Bass | <s>) = 0.0001
# P(Winter | <s>) = 0.0001
# P(Delhi | <s>) = 0.0001
# P(FINNISH | <s>) = 0.0001
# P(Akzo | <s>) = 0.0001
# P(Pioneer | <s>) = 0.0001
# P(Cheung | <s>) = 0.0001
# P(Rexnord | <s>) = 0.0001
# P(Kramer | <s>) = 0.0001
# P(CSCE | <s>) = 0.0001
# P(CFTC | <s>) = 0.0001
# P(CRI | <s>) = 0.0001
# P(Roberts | <s>) = 0.0001
# P(BEGHIN | <s>) = 0.0001
# P(OCCIDENTAL | <s>) = 0.0001
# P(Chirac | <s>) = 0.0001
# P(ILLINOIS | <s>) = 0.0001
# P(PENNZOIL | <s>) = 0.0001
# P(Exploration | <s>) = 0.0001
# P(Weekly | <s>) = 0.0001
# P(Enro | <s>) = 0.0001
# P(Whether | <s>) = 0.0001
# P(AUDITORS | <s>) = 0.0001
# P(Goh | <s>) = 0.0001
# P(June | <s>) = 0.0001
# P(GUARDIAN | <s>) = 0.0001
# P(Ouko | <s>) = 0.0001
# P(R | <s>) = 0.0001
# P(Administration | <s>) = 0.0001
# P(MACANDREWS | <s>) = 0.0001
# P(Anacomp | <s>) = 0.0001
# P(Stephens | <s>) = 0.0001
# P(Accordingly | <s>) = 0.0001
# P(Specifically | <s>) = 0.0001
# P(HUTTON | <s>) = 0.0001
# P(Sunflower | <s>) = 0.0001
# P(Key | <s>) = 0.0001
# P(NOVAMIN | <s>) = 0.0001
# P(Compared | <s>) = 0.0001
# P(Increased | <s>) = 0.0001
# P(Swedish | <s>) = 0.0001
# P(Cuba | <s>) = 0.0001
# P(Cross | <s>) = 0.0001
# P(Vernes | <s>) = 0.0001
# P(Strenger | <s>) = 0.0001
# P(Santa | <s>) = 0.0001
# P(GRAPHIC | <s>) = 0.0001
# P(Interior | <s>) = 0.0001
# P(Krupp | <s>) = 0.0001
# P(AGL | <s>) = 0.0001
# P(GAO | <s>) = 0.0001
# P(Above | <s>) = 0.0001
# P(Testifying | <s>) = 0.0001
# P(Remaining | <s>) = 0.0001
# P(NWA | <s>) = 0.0001
# P(Primary | <s>) = 0.0001
# P(Boschwitz | <s>) = 0.0001
# P(Guinn | <s>) = 0.0001
# P(Real | <s>) = 0.0001
# P(Lo | <s>) = 0.0001
# P(Undersecretary | <s>) = 0.0001
# P(TRANSPORTATION | <s>) = 0.0001
# P(Commission | <s>) = 0.0001
# P(SOGENAL | <s>) = 0.0001
# P(Societe | <s>) = 0.0001
# P(Azzam | <s>) = 0.0001
# P(ARMTEK | <s>) = 0.0001
# P(FERC | <s>) = 0.0001
# P(Avg | <s>) = 0.0001
# P(SOME | <s>) = 0.0001
# P(MONFORT | <s>) = 0.0001
# P(Nationwide | <s>) = 0.0001
# P(CHICAGO | <s>) = 0.0001
# P(SOROS | <s>) = 0.0001
# P(LLOYDS | <s>) = 0.0001
# P(Petrol | <s>) = 0.0001
# P(Dudley | <s>) = 0.0001
# P(Successful | <s>) = 0.0001
# P(Wonnacott | <s>) = 0.0001
# P(ATPC | <s>) = 0.0001
# P(Chief | <s>) = 0.0001
# P(Bolivia | <s>) = 0.0001
# P(Bear | <s>) = 0.0001
# P(RMJ | <s>) = 0.0001
# P(Carolin | <s>) = 0.0001
# P(BUSINESS | <s>) = 0.0001
# P(Solomon | <s>) = 0.0001
# P(Proven | <s>) = 0.0001
# P(Sigma | <s>) = 0.0001
# P(DIAGNOSTIC | <s>) = 0.0001
# P(Improved | <s>) = 0.0001
# P(MHI | <s>) = 0.0001
# P(Dharyono | <s>) = 0.0001
# P(Pittston | <s>) = 0.0001
# P(Frawley | <s>) = 0.0001
# P(Baird | <s>) = 0.0001
# P(DUDLEY | <s>) = 0.0001
# P(Chemlawn | <s>) = 0.0001
# P(Alusuisse | <s>) = 0.0001
# P(Service | <s>) = 0.0001
# P(Interconnect | <s>) = 0.0001
# P(Varity | <s>) = 0.0001
# P(Work | <s>) = 0.0001
# P(Ongpin | <s>) = 0.0001
# P(MADAGASCAR | <s>) = 0.0001
# P(AVAQ | <s>) = 0.0001
# P(Martens | <s>) = 0.0001
# P(WEDGE | <s>) = 0.0001
# P(Norwegian | <s>) = 0.0001
# P(LEAR | <s>) = 0.0001
# P(INL | <s>) = 0.0001
# P(TransAmerican | <s>) = 0.0001
# P(JAMESWAY | <s>) = 0.0001
# P(Audi | <s>) = 0.0001
# P(Wiehn | <s>) = 0.0001
# P(Carolina | <s>) = 0.0001
# P(SWISSAIR | <s>) = 0.0001
# P(Rospatch | <s>) = 0.0001
# P(Kansas | <s>) = 0.0001
# P(Quaker | <s>) = 0.0001
# P(Geodome | <s>) = 0.0001
# P(Ecolab | <s>) = 0.0001
# P(Moore | <s>) = 0.0001
# P(Wickes | <s>) = 0.0001
# P(SWIRE | <s>) = 0.0001
# P(Evans | <s>) = 0.0001
# P(Claremont | <s>) = 0.0001
# P(OII | <s>) = 0.0001
# P(EXCHANGE | <s>) = 0.0001
# P(Miles | <s>) = 0.0001
# P(Meinhardt | <s>) = 0.0001
# P(MULFORD | <s>) = 0.0001
# P(Retaliation | <s>) = 0.0001
# P(Rubber | <s>) = 0.0001
# P(SUBROTO | <s>) = 0.0001
# P(Atlas | <s>) = 0.0001
# P(Demands | <s>) = 0.0001
# P(Wants | <s>) = 0.0001
# P(Kuroda | <s>) = 0.0001
# P(Cojuangco | <s>) = 0.0001
# P(San | <s>) = 0.0001
# P(HIGHER | <s>) = 0.0001
# P(Immediately | <s>) = 0.0001
# P(INDEPENDENT | <s>) = 0.0001
# P(Received | <s>) = 0.0001
# P(Paris | <s>) = 0.0001
# P(ALEX | <s>) = 0.0001
# P(FURTHER | <s>) = 0.0001
# P(Rains | <s>) = 0.0001
# P(Harvest | <s>) = 0.0001
# P(ATLAS | <s>) = 0.0001
# P(FIDELCOR | <s>) = 0.0001
# P(Murray | <s>) = 0.0001
# P(REUTERS | <s>) = 0.0001
# P(Reuters | <s>) = 0.0001
# P(CCL | <s>) = 0.0001
# P(Montedison | <s>) = 0.0001
# P(DATRON | <s>) = 0.0001
# P(TUNISIA | <s>) = 0.0001
# P(Saunders | <s>) = 0.0001
# P(ORANGE | <s>) = 0.0001
# P(Africa | <s>) = 0.0001
# P(FRONTIER | <s>) = 0.0001
# P(CATERPILLAR | <s>) = 0.0001
# P(MEDTRONIC | <s>) = 0.0001
# P(TALKS | <s>) = 0.0001
# P(HARTMARX | <s>) = 0.0001
# P(Morrison | <s>) = 0.0001
# P(Subcommittee | <s>) = 0.0001
# P(RITE | <s>) = 0.0001
# P(Xebec | <s>) = 0.0001
# P(VULCAN | <s>) = 0.0001
# P(Comments | <s>) = 0.0001
# P(MANAGEMENT | <s>) = 0.0001
# P(INTERCARE | <s>) = 0.0001
# P(SUPER | <s>) = 0.0001
# P(ON | <s>) = 0.0001
# P("... | <s>) = 0.0001
# P(Koehler | <s>) = 0.0001
# P(Speculative | <s>) = 0.0001
# P(Critics | <s>) = 0.0001
# P(Burmah | <s>) = 0.0001
# P(Minorities | <s>) = 0.0001
# P(Takashi | <s>) = 0.0001
# P(PLDT | <s>) = 0.0001
# P(Just | <s>) = 0.0001
# P(9 | <s>) = 0.0001
# P(Merchandise | <s>) = 0.0001
# P(Dave | <s>) = 0.0001
# P(Holdings | <s>) = 0.0001
# P(WHIRLPOOL | <s>) = 0.0001
# P(Aside | <s>) = 0.0001
# P(Responding | <s>) = 0.0001
# P(MINAS | <s>) = 0.0001
# P(IMF | <s>) = 0.0001
# P(REXHAM | <s>) = 0.0001
# P(ASARCO | <s>) = 0.0001
# P(FREDDIE | <s>) = 0.0001
# P(Rexham | <s>) = 0.0001
# P(Rebates | <s>) = 0.0001
# P(Bill | <s>) = 0.0001
# P(Koch | <s>) = 0.0001
# P(MET | <s>) = 0.0001
# P(Armco | <s>) = 0.0001
# P(EASTERN | <s>) = 0.0001
# P(Yield | <s>) = 0.0001
# P(WEATHER | <s>) = 0.0001
# P(JP | <s>) = 0.0001
# P(ELEVATOR | <s>) = 0.0001
# P(Reference | <s>) = 0.0001
# P(Toledo | <s>) = 0.0001
# P(River | <s>) = 0.0001
# P(Proved | <s>) = 0.0001
# P(MARCH | <s>) = 0.0001
# P(RETAILERS | <s>) = 0.0001
# P(Projected | <s>) = 0.0001
# P(CONGRESSMAN | <s>) = 0.0001
# P(Usage | <s>) = 0.0001
# P(ALL | <s>) = 0.0001
# P(BARLEY | <s>) = 0.0001
# P(COTTON | <s>) = 0.0001
# P(JAMES | <s>) = 0.0001
# P(THREE | <s>) = 0.0001
# P(PETROLEUM | <s>) = 0.0001
# P(Sony | <s>) = 0.0001
# P(Development | <s>) = 0.0001
# P(FCOJ | <s>) = 0.0001
# P(LA | <s>) = 0.0001
# P(CRUDE | <s>) = 0.0001
# P(Nerco | <s>) = 0.0001
# P(CADILLAC | <s>) = 0.0001
# P(Wednesday | <s>) = 0.0001
# P(TRADING | <s>) = 0.0001
# P(Marris | <s>) = 0.0001
# P(AVERAGE | <s>) = 0.0001
# P(Throughout | <s>) = 0.0001
# P(YIELD | <s>) = 0.0001
# P(Registered | <s>) = 0.0001
# P(PATON | <s>) = 0.0001
# P(Calgary | <s>) = 0.0001
# P(AWB | <s>) = 0.0001
# P(Norcros | <s>) = 0.0001
# P(STATOIL | <s>) = 0.0001
# P(HILLSDOWN | <s>) = 0.0001
# P(Singapore | <s>) = 0.0001
# P(BANGEMANN | <s>) = 0.0001
# P(Portugal | <s>) = 0.0001
# P(Independence | <s>) = 0.0001
# P(Columbia | <s>) = 0.0001
# P(Tariff | <s>) = 0.0001
# P(Klopfenstein | <s>) = 0.0001
# P(GIANT | <s>) = 0.0001
# P(13 | <s>) = 0.0001
# P(AFG | <s>) = 0.0001
# P(Commonwealth | <s>) = 0.0001
# P(ENTRE | <s>) = 0.0001
# P(Fields | <s>) = 0.0001
# ...
# P(SOLAR | <s>) = 0.0000
# P(Solar | <s>) = 0.0000
# P(INKEY | <s>) = 0.0000
# P(Inkey | <s>) = 0.0000
# P(DEP | <s>) = 0.0000
# P(Clements | <s>) = 0.0000
# P(Barker | <s>) = 0.0000
# P(Quite | <s>) = 0.0000
# P(M0 | <s>) = 0.0000
# P(Transit | <s>) = 0.0000
# P(BURNUP | <s>) = 0.0000
# P(Pfaudler | <s>) = 0.0000
# P(KMS | <s>) = 0.0000
# P(SYNTECH | <s>) = 0.0000
# P(POP | <s>) = 0.0000
# P(Pitman | <s>) = 0.0000
# P(ERBAMONT | <s>) = 0.0000
# P(CONGRESSMEN | <s>) = 0.0000
# P(RAISE | <s>) = 0.0000
# P(Citrosuco | <s>) = 0.0000
# P(ALDEN | <s>) = 0.0000
# P(Alden | <s>) = 0.0000
# P(Jacoby | <s>) = 0.0000
# P(AZURE | <s>) = 0.0000
# P(Absorption | <s>) = 0.0000
# P(ODYSSEY | <s>) = 0.0000
# P(Improvements | <s>) = 0.0000
# P(BOMBAY | <s>) = 0.0000
# P(HELDOR | <s>) = 0.0000
# P(Perrin | <s>) = 0.0000
# P(Joan | <s>) = 0.0000
# P(Hanbury | <s>) = 0.0000
# P(Medium | <s>) = 0.0000
# P(AMBASSADOR | <s>) = 0.0000
# P(ASEA | <s>) = 0.0000
# P(Asea | <s>) = 0.0000
# P(ART | <s>) = 0.0000
# P(Art | <s>) = 0.0000
# P(PSE | <s>) = 0.0000
# P(Ward | <s>) = 0.0000
# P(Sherwoood | <s>) = 0.0000
# P(NORRIS | <s>) = 0.0000
# P(DORSEY | <s>) = 0.0000
# P(Napco | <s>) = 0.0000
# P(Cineplex | <s>) = 0.0000
# P(GOULDS | <s>) = 0.0000
# P(Henkel | <s>) = 0.0000
# P(Byron | <s>) = 0.0000
# P(INTERMARK | <s>) = 0.0000
# P(JOSTEN | <s>) = 0.0000
# P(Proprietary | <s>) = 0.0000
# P(NRM | <s>) = 0.0000
# P(MOTEL | <s>) = 0.0000
# P(TAG | <s>) = 0.0000
# P(HARMON | <s>) = 0.0000
# P(Alfaro | <s>) = 0.0000
# P(MICROPRO | <s>) = 0.0000
# P(Garment | <s>) = 0.0000
# P(Shanghai | <s>) = 0.0000
# P(Ningbo | <s>) = 0.0000
# P(Attractive | <s>) = 0.0000
# P(KRUNG | <s>) = 0.0000
# P(Sayam | <s>) = 0.0000
# P(Waree | <s>) = 0.0000
# P(Krung | <s>) = 0.0000
# P(KOMATSU | <s>) = 0.0000
# P(KIRIN | <s>) = 0.0000
# P(Severe | <s>) = 0.0000
# P(PASAR | <s>) = 0.0000
# P(Bhagat | <s>) = 0.0000
# P(TROPICAL | <s>) = 0.0000
# P(Replanting | <s>) = 0.0000
# P(Ganapin | <s>) = 0.0000
# P(Prescriptions | <s>) = 0.0000
# P(Deforestation | <s>) = 0.0000
# P(Sponsored | <s>) = 0.0000
# P(WWF | <s>) = 0.0000
# P(Expenditure | <s>) = 0.0000
# P(XP | <s>) = 0.0000
# P(Collins | <s>) = 0.0000
# P(Hawkins | <s>) = 0.0000
# P(NEWMAN | <s>) = 0.0000
# P(Agencies | <s>) = 0.0000
# P(Calculations | <s>) = 0.0000
# P(Berliner | <s>) = 0.0000
# P(BIOSEARCH | <s>) = 0.0000
# P(Unfair | <s>) = 0.0000
# P(Zdzislaw | <s>) = 0.0000
# P(Stanely | <s>) = 0.0000
# P(SONEX | <s>) = 0.0000
# P(Sonex | <s>) = 0.0000
# P(COMPUSCAN | <s>) = 0.0000
# P(analysts | <s>) = 0.0000
# P(METALLGESELLSCHAFT | <s>) = 0.0000
# P(RENT | <s>) = 0.0000
# P(CARTERET | <s>) = 0.0000
# P(McDonald | <s>) = 0.0000
# P(ENVIROPACT | <s>) = 0.0000
# P(WHITEHALL | <s>) = 0.0000
# P(VIRATECK | <s>) = 0.0000
# P(PARKWAY | <s>) = 0.0000
# P(Exceptions | <s>) = 0.0000
# P(Credits | <s>) = 0.0000
# P(PARISIAN | <s>) = 0.0000
# P(SPI | <s>) = 0.0000
# P(COGECO | <s>) = 0.0000
# P(GRACO | <s>) = 0.0000
# P(SCAT | <s>) = 0.0000
# P(BALANCE | <s>) = 0.0000
# P(RECOMMENDATION | <s>) = 0.0000
# P(WINTHROP | <s>) = 0.0000
# P(BROKE | <s>) = 0.0000
# P(AUTOCLAVE | <s>) = 0.0000
# P(Presented | <s>) = 0.0000
# P(Bergsten | <s>) = 0.0000
# P(Rimmer | <s>) = 0.0000
# P(REALMERICA | <s>) = 0.0000
# P(Billboard | <s>) = 0.0000
# P(Affiliated | <s>) = 0.0000
# P(CELINA | <s>) = 0.0000
# P(GENERALE | <s>) = 0.0000
# P(SA | <s>) = 0.0000
# P(VIRCO | <s>) = 0.0000
# P(SHL | <s>) = 0.0000
# P(Slab | <s>) = 0.0000
# P(PHOTRONIC | <s>) = 0.0000
# P(ARMSTRONG | <s>) = 0.0000
# P(FERRO | <s>) = 0.0000
# P(Shutting | <s>) = 0.0000
# P(UN | <s>) = 0.0000
# P(Ahmed | <s>) = 0.0000
# P(Hiram | <s>) = 0.0000
# P(Carlos | <s>) = 0.0000
# P(Pensions | <s>) = 0.0000
# P(FISH | <s>) = 0.0000
# P(EFPs | <s>) = 0.0000
# P(Tel | <s>) = 0.0000
# P(MCM | <s>) = 0.0000
# P(THACKERAY | <s>) = 0.0000
# P(CONCERN | <s>) = 0.0000
# P(Water | <s>) = 0.0000
# P(Integrated | <s>) = 0.0000
# P(Inflows | <s>) = 0.0000
# P(Sixteen | <s>) = 0.0000
# P(Navistar | <s>) = 0.0000
# P(Eisenberg | <s>) = 0.0000
# P(Virazole | <s>) = 0.0000
# P(JUSTIN | <s>) = 0.0000
# P(SCHOLASTIC | <s>) = 0.0000
# P(PEPS | <s>) = 0.0000
# P(FREIGHT | <s>) = 0.0000
# P(Yankee | <s>) = 0.0000
# P(WENDY | <s>) = 0.0000
# P(EMERALD | <s>) = 0.0000
# P(Emerald | <s>) = 0.0000
# P(BINKS | <s>) = 0.0000
# P(NIAGARA | <s>) = 0.0000
# P(Niagara | <s>) = 0.0000
# P(LDC | <s>) = 0.0000
# P(Sugarcane | <s>) = 0.0000
# P(QUANTITY | <s>) = 0.0000
# P(Fundamentals | <s>) = 0.0000
# P(Depressed | <s>) = 0.0000
# P(Hemsley | <s>) = 0.0000
# P(Falcon | <s>) = 0.0000
# P(BIDS | <s>) = 0.0000
# P(SUNBELT | <s>) = 0.0000
# P(MARCOM | <s>) = 0.0000
# P(Ottawa | <s>) = 0.0000
# P(STANWOOD | <s>) = 0.0000
# P(SULPETRO | <s>) = 0.0000
# P(Sulpetro | <s>) = 0.0000
# P(NATURAL | <s>) = 0.0000
# P(Spadine | <s>) = 0.0000
# P(AGA | <s>) = 0.0000
# P(Smolinski | <s>) = 0.0000
# P(Paz | <s>) = 0.0000
# P(MAIN | <s>) = 0.0000
# P(Giving | <s>) = 0.0000
# P(Suharto | <s>) = 0.0000
# P(SFEM | <s>) = 0.0000
# P(Ishrat | <s>) = 0.0000
# P(Bumper | <s>) = 0.0000
# P(Panganiban | <s>) = 0.0000
# P(Ariadne | <s>) = 0.0000
# P(Complete | <s>) = 0.0000
# P(RAIMOND | <s>) = 0.0000
# P(GCC | <s>) = 0.0000
# P(EXPLOSION | <s>) = 0.0000
# P(Commissioner | <s>) = 0.0000
# P(Alitalia | <s>) = 0.0000
# P(RAFIDAIN | <s>) = 0.0000
# P(Rafidain | <s>) = 0.0000
# P(Jorio | <s>) = 0.0000
# P(ARIADNE | <s>) = 0.0000
# P(Newspapers | <s>) = 0.0000
# P(Policymakers | <s>) = 0.0000
# P(Increasing | <s>) = 0.0000
# P(Story | <s>) = 0.0000
# P(Windfall | <s>) = 0.0000
# P(Cutting | <s>) = 0.0000
# P(Mamman | <s>) = 0.0000
# P(Developed | <s>) = 0.0000
# P(Josef | <s>) = 0.0000
# P(BURMA | <s>) = 0.0000
# P(Debt | <s>) = 0.0000
# P(Scrap | <s>) = 0.0000
# P(DENG | <s>) = 0.0000
# P(Accounted | <s>) = 0.0000
# P(Commitments | <s>) = 0.0000
# P(Kaysersberg | <s>) = 0.0000
# P(23 | <s>) = 0.0000
# P(DRESDNER | <s>) = 0.0000
# P(AWF | <s>) = 0.0000
# P(PITTWAY | <s>) = 0.0000
# P(GOOD | <s>) = 0.0000
# P(Armstrong | <s>) = 0.0000
# P(CASH | <s>) = 0.0000
# P(Sebaana | <s>) = 0.0000
# P(Agreement | <s>) = 0.0000
# P(Harbour | <s>) = 0.0000
# P(Microtel | <s>) = 0.0000
# P(Winthrop | <s>) = 0.0000
# P(Formation | <s>) = 0.0000
# P(FRUIT | <s>) = 0.0000
# P(CITYQUEST | <s>) = 0.0000
# P(Undertakings | <s>) = 0.0000
# P(Cityquest | <s>) = 0.0000
# P(WINCHELL | <s>) = 0.0000
# P(AAR | <s>) = 0.0000
# P(CLAIR | <s>) = 0.0000
# P(ALCO | <s>) = 0.0000
# P(Normal | <s>) = 0.0000
# P(RYLAND | <s>) = 0.0000
# P(FULLER | <s>) = 0.0000
# P(PETROLITE | <s>) = 0.0000
# P(WESTWORLD | <s>) = 0.0000
# P(PAYCHEX | <s>) = 0.0000
# P(HEMODYNAMICS | <s>) = 0.0000
# P(DELOITTE | <s>) = 0.0000
# P(ZINC | <s>) = 0.0000
# P(CHILD | <s>) = 0.0000
# P(BAYERNVEREIN | <s>) = 0.0000
# P(Risk | <s>) = 0.0000
# P(Paragon | <s>) = 0.0000
# P(Operation | <s>) = 0.0000
# P(Adler | <s>) = 0.0000
# P(Photo | <s>) = 0.0000
# P(RECOTON | <s>) = 0.0000
# P(SANFORD | <s>) = 0.0000
# P(HOSPOSABLE | <s>) = 0.0000
# P(Vogel | <s>) = 0.0000
# P(Die | <s>) = 0.0000
# P(Vague | <s>) = 0.0000
# P(Leucadia | <s>) = 0.0000
# P(PRINCIPAL | <s>) = 0.0000
# P(Coceral | <s>) = 0.0000
# P(DUCOMMON | <s>) = 0.0000
# P(MICROBIO | <s>) = 0.0000
# P(Microbiological | <s>) = 0.0000
# P(INA | <s>) = 0.0000
# P(JUNO | <s>) = 0.0000
# P(Rayner | <s>) = 0.0000
# P(PREPARED | <s>) = 0.0000
# P(TIMBER | <s>) = 0.0000
# P(Lechin | <s>) = 0.0000
# P(Weizsaecker | <s>) = 0.0000
# P(Written | <s>) = 0.0000
# P(PACIFICARE | <s>) = 0.0000
# P(INITIALS | <s>) = 0.0000
# P(Initials | <s>) = 0.0000
# P(Murren | <s>) = 0.0000
# P(Caroline | <s>) = 0.0000
# P(Pepsi | <s>) = 0.0000
# P(GEMINI | <s>) = 0.0000
# P(SOCIETE | <s>) = 0.0000
# P(CES | <s>) = 0.0000
# P(Disinflation | <s>) = 0.0000
# P(KIDDIE | <s>) = 0.0000
# P(TELECREDIT | <s>) = 0.0000
# P(BellSouth | <s>) = 0.0000
# P(BANCA | <s>) = 0.0000
# P(LESCO | <s>) = 0.0000
# P(SEISMIC | <s>) = 0.0000
# P(VARLEN | <s>) = 0.0000
# P(ANALYSIS | <s>) = 0.0000
# P(Taqi | <s>) = 0.0000
# P(CANTREX | <s>) = 0.0000
# P(PRIMARK | <s>) = 0.0000
# P(SAXON | <s>) = 0.0000
# P(BRUNSWICK | <s>) = 0.0000
# P(Reichart | <s>) = 0.0000
# P(Frederick | <s>) = 0.0000
# P(DRIVER | <s>) = 0.0000
# P(Perceptive | <s>) = 0.0000
# P(Vernell | <s>) = 0.0000
# P(STOKELY | <s>) = 0.0000
# P(Hecla | <s>) = 0.0000
# P(SPRINT | <s>) = 0.0000
# P(Fiber | <s>) = 0.0000
# P(AVALON | <s>) = 0.0000
# P(Look | <s>) = 0.0000
# P(Hindsight | <s>) = 0.0000
# P(BAY | <s>) = 0.0000
# P(Aviation | <s>) = 0.0000
# P(Hoare | <s>) = 0.0000
# P(Santi | <s>) = 0.0000
# P(PENINSULAR | <s>) = 0.0000
# P(Somehow | <s>) = 0.0000
# P(Human | <s>) = 0.0000
# P(Lisbon | <s>) = 0.0000
# P(Interference | <s>) = 0.0000
# P(Whipple | <s>) = 0.0000
# P(Helped | <s>) = 0.0000
# P(Tension | <s>) = 0.0000
# P(BDM | <s>) = 0.0000
# P(STORM | <s>) = 0.0000
# P(Flash | <s>) = 0.0000
# P(Gale | <s>) = 0.0000
# P(Electrical | <s>) = 0.0000
# P(IRELAND | <s>) = 0.0000
# P(Opinion | <s>) = 0.0000
# P(TRANSNATIONAL | <s>) = 0.0000
# P(Narusawa | <s>) = 0.0000
# P(ANGELICA | <s>) = 0.0000
# P(GULL | <s>) = 0.0000
# P(AMERIANA | <s>) = 0.0000
# P(GRIFFIN | <s>) = 0.0000
# P(Levy | <s>) = 0.0000
# P(ARGYLL | <s>) = 0.0000
# P(Disclosures | <s>) = 0.0000
# P(VALLEN | <s>) = 0.0000
# P(stock | <s>) = 0.0000
# P(common | <s>) = 0.0000
# P(ASTROTECH | <s>) = 0.0000
# P(PNEUMATIC | <s>) = 0.0000
# P(HYDRAULIC | <s>) = 0.0000
# P(PREWAY | <s>) = 0.0000
# P(SUNA | <s>) = 0.0000
# P(Twenty | <s>) = 0.0000
# P(Bookings | <s>) = 0.0000
# P(QUARTERLY | <s>) = 0.0000
# P(Borrowing | <s>) = 0.0000
# P(KLEINERT | <s>) = 0.0000
# P(MICRODYME | <s>) = 0.0000
# P(Restructuring | <s>) = 0.0000
# P(Jaap | <s>) = 0.0000
# P(Haslam | <s>) = 0.0000
# P(Reid | <s>) = 0.0000
# P(GNB | <s>) = 0.0000
# P(Taco | <s>) = 0.0000
# P(Commodities | <s>) = 0.0000
# P(Lamborghini | <s>) = 0.0000
# P(KUNA | <s>) = 0.0000
# P(Extraordinaries | <s>) = 0.0000
# P(Rugeroni | <s>) = 0.0000
# P(DRAWDOWN | <s>) = 0.0000
# P(Expectations | <s>) = 0.0000
# P(Bullish | <s>) = 0.0000
# P(Worries | <s>) = 0.0000
# P(PLENUM | <s>) = 0.0000
# P(HONEYBEE | <s>) = 0.0000
# P(CIF | <s>) = 0.0000
# P(Businesses | <s>) = 0.0000
# P(OLIVETTI | <s>) = 0.0000
# P(Stet | <s>) = 0.0000
# P(ENSERCH | <s>) = 0.0000
# P(Nabisco | <s>) = 0.0000
# P(MICROSIZE | <s>) = 0.0000
# P(Fuller | <s>) = 0.0000
# P(TAJON | <s>) = 0.0000
# P(CENTERIOR | <s>) = 0.0000
# P(Membership | <s>) = 0.0000
# P(Mulligan | <s>) = 0.0000
# P(Cavanaugh | <s>) = 0.0000
# P(Patronage | <s>) = 0.0000
# P(Hokanson | <s>) = 0.0000
# P(Joining | <s>) = 0.0000
# P(CROWLEY | <s>) = 0.0000
# P(Procedure | <s>) = 0.0000
# P(CALUMET | <s>) = 0.0000
# P(Salvino | <s>) = 0.0000
# P(Nimit | <s>) = 0.0000
# P(Nonthapanthawat | <s>) = 0.0000
# P(Revision | <s>) = 0.0000
# P(Earnest | <s>) = 0.0000
# P(MOTT | <s>) = 0.0000
# P(Mobex | <s>) = 0.0000
# P(Siemen | <s>) = 0.0000
# P(Haiti | <s>) = 0.0000
# P(Czechoslovakia | <s>) = 0.0000
# P(WEAN | <s>) = 0.0000
# P(first | <s>) = 0.0000
# P(FISONS | <s>) = 0.0000
# P(Chia | <s>) = 0.0000
# P(SUNDOR | <s>) = 0.0000
# P(QUICK | <s>) = 0.0000
# P(NUMEREX | <s>) = 0.0000
# P(UNIONIST | <s>) = 0.0000
# P(MIDIVEST | <s>) = 0.0000
# P(Midivest | <s>) = 0.0000
# P(Talk | <s>) = 0.0000
# P(Noverco | <s>) = 0.0000
# P(NASHUA | <s>) = 0.0000
# P(ALTRON | <s>) = 0.0000
# P(VERMONT | <s>) = 0.0000
# P(GARTNER | <s>) = 0.0000
# P(Gartner | <s>) = 0.0000
# P(Solters | <s>) = 0.0000
# P(Braddock | <s>) = 0.0000
# P(WD | <s>) = 0.0000
# P(NIPSCO | <s>) = 0.0000
# P(Expected | <s>) = 0.0000
# P(KIRSCHNER | <s>) = 0.0000
# P(Grassley | <s>) = 0.0000
# P(MARYLAND | <s>) = 0.0000
# P(Chacin | <s>) = 0.0000
# P(Reimpell | <s>) = 0.0000
# P(GOTTSCHALKS | <s>) = 0.0000
# P(Potash | <s>) = 0.0000
# P(TRINTOC | <s>) = 0.0000
# P(Ramnath | <s>) = 0.0000
# P(Snamprogetti | <s>) = 0.0000
# P(Trintoc | <s>) = 0.0000
# P(Robinson | <s>) = 0.0000
# P(Siaahan | <s>) = 0.0000
# P(Los | <s>) = 0.0000
# P(MIKRON | <s>) = 0.0000
# P(AUSTN | <s>) = 0.0000
# P(MERGERS | <s>) = 0.0000
# P(Dealerships | <s>) = 0.0000
# P(Power | <s>) = 0.0000
# P(Offering | <s>) = 0.0000
# P(CHAPMAN | <s>) = 0.0000
# P(Troon | <s>) = 0.0000
# P(WEEKS | <s>) = 0.0000
# P(Assistant | <s>) = 0.0000
# P(Panin | <s>) = 0.0000
# P(Madagascar | <s>) = 0.0000
# P(Roland | <s>) = 0.0000
# P(Man | <s>) = 0.0000
# P(Jeddah | <s>) = 0.0000
# P(Riyal | <s>) = 0.0000
# P(INJUNCTION | <s>) = 0.0000
# P(Projects | <s>) = 0.0000
# P(BICC | <s>) = 0.0000
# P(Attributable | <s>) = 0.0000
# P(Month | <s>) = 0.0000
# P(Ayala | <s>) = 0.0000
# P(Big | <s>) = 0.0000
# P(STC | <s>) = 0.0000
# P(MIXED | <s>) = 0.0000
# P(CIBA | <s>) = 0.0000
# P(Polyphenylene | <s>) = 0.0000
# P(Extruded | <s>) = 0.0000
# P(UNCERTAINTY | <s>) = 0.0000
# P(Sassan | <s>) = 0.0000
# P(Fluctuating | <s>) = 0.0000
# P(Inventories | <s>) = 0.0000
# P(Your | <s>) = 0.0000
# P(DURIRON | <s>) = 0.0000
# P(ROWLEY | <s>) = 0.0000
# P(Rowley | <s>) = 0.0000
# P(CAYACQ | <s>) = 0.0000
# P(Fesharaki | <s>) = 0.0000
# P(MCFARLAND | <s>) = 0.0000
# P(TIMMINCO | <s>) = 0.0000
# P(Timminco | <s>) = 0.0000
# P(VANGUARD | <s>) = 0.0000
# P(AVATAR | <s>) = 0.0000
# P(Blocks | <s>) = 0.0000
# P(PERCEPTION | <s>) = 0.0000
# P(Perception | <s>) = 0.0000
# P(CROSSLAND | <s>) = 0.0000
# P(CrossLand | <s>) = 0.0000
# P(Crossland | <s>) = 0.0000
# P(VICORP | <s>) = 0.0000
# P(FABRI | <s>) = 0.0000
# P(Preventive | <s>) = 0.0000
# P(Jack | <s>) = 0.0000
# P(STOCKHOLDER | <s>) = 0.0000
# P(Software | <s>) = 0.0000
# P(CONCEPT | <s>) = 0.0000
# P(Johannesburg | <s>) = 0.0000
# P(MAYTAG | <s>) = 0.0000
# P(Maytag | <s>) = 0.0000
# P(INTN | <s>) = 0.0000
# P(Conclusion | <s>) = 0.0000
# P(WESTWOOD | <s>) = 0.0000
# P(Mousavi | <s>) = 0.0000
# P(TRICENTROL | <s>) = 0.0000
# P(Tricentrol | <s>) = 0.0000
# P(Novamin | <s>) = 0.0000
# P(COMMONWEALTY | <s>) = 0.0000
# P(SUNSTAR | <s>) = 0.0000
# P(ROSS | <s>) = 0.0000
# P(Lennox | <s>) = 0.0000
# P(Melcher | <s>) = 0.0000
# P(Sheehy | <s>) = 0.0000
# P(BI | <s>) = 0.0000
# P(MONTANA | <s>) = 0.0000
# P(TEAM | <s>) = 0.0000
# P(RSI | <s>) = 0.0000
# P(RCM | <s>) = 0.0000
# P(SYNALLOY | <s>) = 0.0000
# P(Options | <s>) = 0.0000
# P(IMO | <s>) = 0.0000
# P(MESSIDOR | <s>) = 0.0000
# P(Messidor | <s>) = 0.0000
# P(HERSHEY | <s>) = 0.0000
# P(EG | <s>) = 0.0000
# P(48 | <s>) = 0.0000
# P(Bankworkers | <s>) = 0.0000
# P(Hardly | <s>) = 0.0000
# P(Gateway | <s>) = 0.0000
# P(Middle | <s>) = 0.0000
# P(Insider | <s>) = 0.0000
# P(Where | <s>) = 0.0000
# P(SUMMIT | <s>) = 0.0000
# P(Labatt | <s>) = 0.0000
# P(HUSKY | <s>) = 0.0000
# P(PUERTO | <s>) = 0.0000
# P(WESCO | <s>) = 0.0000
# P(Bamberger | <s>) = 0.0000
# P(AMPAL | <s>) = 0.0000
# P(Restrictions | <s>) = 0.0000
# P(Medar | <s>) = 0.0000
# P(NIKE | <s>) = 0.0000
# P(REDKIN | <s>) = 0.0000
# P(NORDSON | <s>) = 0.0000
# P(Lai | <s>) = 0.0000
# P(Ealier | <s>) = 0.0000
# P(NORMAL | <s>) = 0.0000
# P(Wellington | <s>) = 0.0000
# P(Divestitures | <s>) = 0.0000
# P(CRYSTAL | <s>) = 0.0000
# P(Politically | <s>) = 0.0000
# P(Cochran | <s>) = 0.0000
# P(FIDUCIARY | <s>) = 0.0000
# P(Boise | <s>) = 0.0000
# P(BRYSON | <s>) = 0.0000
# P(Cenergy | <s>) = 0.0000
# P(Kanasa | <s>) = 0.0000
# P(ICC | <s>) = 0.0000
# P(Cyril | <s>) = 0.0000
# P(Automation | <s>) = 0.0000
# P(RKO | <s>) = 0.0000
# P(Campbell | <s>) = 0.0000
# P(METROBANC | <s>) = 0.0000
# P(Metrobanc | <s>) = 0.0000
# P(GV | <s>) = 0.0000
# P(COST | <s>) = 0.0000
# P(Eliminating | <s>) = 0.0000
# P(DAILY | <s>) = 0.0000
# P(FRIEDMAN | <s>) = 0.0000
# P(PENOBSCOT | <s>) = 0.0000
# P(ASHTON | <s>) = 0.0000
# P(CONSOLIDATE | <s>) = 0.0000
# P(NEITHER | <s>) = 0.0000
# P(PSC | <s>) = 0.0000
# P(Depreciation | <s>) = 0.0000
# P(Spedding | <s>) = 0.0000
# P(Largely | <s>) = 0.0000
# P(Roussel | <s>) = 0.0000
# P(Celanese | <s>) = 0.0000
# P(Related | <s>) = 0.0000
# P(Reorganisation | <s>) = 0.0000
# P(Phillip | <s>) = 0.0000
# P(Produced | <s>) = 0.0000
# P(Telecommunications | <s>) = 0.0000
# P(MONETARY | <s>) = 0.0000
# P(Apparent | <s>) = 0.0000
# P(Pleas | <s>) = 0.0000
# P(COMMISSION | <s>) = 0.0000
# P(GREENWOOD | <s>) = 0.0000
# P(Faster | <s>) = 0.0000
# P(Alternative | <s>) = 0.0000
# P(Ayer | <s>) = 0.0000
# P(Mickelberry | <s>) = 0.0000
# P(PHILIPS | <s>) = 0.0000
# P(Equitorial | <s>) = 0.0000
# P(ETHYL | <s>) = 0.0000
# P(Nelson | <s>) = 0.0000
# P(Ideas | <s>) = 0.0000
# P(CAROLIAN | <s>) = 0.0000
# P(Carolian | <s>) = 0.0000
# P(Neoax | <s>) = 0.0000
# P(Novatronics | <s>) = 0.0000
# P(Gevirtz | <s>) = 0.0000
# P(Anchor | <s>) = 0.0000
# P(Historical | <s>) = 0.0000
# P(PHLCORP | <s>) = 0.0000
# P(Alliance | <s>) = 0.0000
# P(Z | <s>) = 0.0000
# P(Petroleos | <s>) = 0.0000
# P(ROY | <s>) = 0.0000
# P(Blockbuster | <s>) = 0.0000
# P(Thermo | <s>) = 0.0000
# P(FRUEHAUF | <s>) = 0.0000
# P(Krestmark | <s>) = 0.0000
# P(Dallas | <s>) = 0.0000
# P(CTI | <s>) = 0.0000
# P(COMSTOCK | <s>) = 0.0000
# P(MILASTAR | <s>) = 0.0000
# P(LIBYA | <s>) = 0.0000
# P(Philips | <s>) = 0.0000
# P(NORCEN | <s>) = 0.0000
# P(CRITICISM | <s>) = 0.0000
# P(Baur | <s>) = 0.0000
# P(LANCER | <s>) = 0.0000
# P(NICHOLS | <s>) = 0.0000
# P(HealthMate | <s>) = 0.0000
# P(HDE | <s>) = 0.0000
# P(Hinrichs | <s>) = 0.0000
# P(KNIGHT | <s>) = 0.0000
# P(AUTOMOTIVE | <s>) = 0.0000

# %% [markdown]
# #### Generating text
#
# Now that we have a bigram model, we can generate text based on it.

# %%
import random

text = ["<s>"]

while text[-1] != "</s>":
    current_word = text[-1]
    
    if current_word not in bi_model:
        break

    next_words, probabilities = zip(*bi_model[current_word].items())

    next_word = random.choices(next_words, weights=probabilities, k=1)[0]

    text.append(next_word)
    print(next_word)

print(' '.join([t for t in text if t not in ("<s>", "</s>")]))
# Out:
# Brazil
# '
# S
# .
# </s>
# Brazil ' S .

# %% [markdown]
# ## Trigram model
#
# In a trigram model, we'll compute the probability of each word given the previous two words as context. To obtain trigrams, we can use NLTK's [trigrams](https://www.nltk.org/_modules/nltk/util.html#trigrams).

# %%
# your code here
from collections import defaultdict
from nltk import trigrams
from nltk.corpus import reuters

# Create a placeholder for the trigram model
tri_model = defaultdict(lambda: defaultdict(lambda: 0))

# Count the frequency of each trigram
for sentence in reuters.sents():
    for w1, w2, w3 in trigrams(sentence, pad_right=True, pad_left=True, left_pad_symbol='<s>', right_pad_symbol='</s>'):
        tri_model[(w1, w2)][w3] += 1  # Store count of w3 given (w1, w2)

# Convert counts to probabilities
for w1_w2 in tri_model:
    total_count = sum(tri_model[w1_w2].values())  # Total occurrences of (w1, w2)
    for w3 in tri_model[w1_w2]:
        tri_model[w1_w2][w3] /= total_count  # Normalize to get probabilities

# The model now contains P(w3 | w1, w2)

# %% [markdown]
# #### Likely triplets
#
# What are the most likely words following "today the"?
# What about "England has"?

# %%
def get_most_likely_words(context, model, top_n=5):
    if context in model:
        sorted_words = sorted(model[context].items(), key=lambda x: x[1], reverse=True)
        print(f"Most likely words following {context}:")
        for w3, prob in sorted_words[:top_n]:  # Show top N most likely words
            print(f"P({w3} | {context}) = {prob:.4f}")
    else:
        print(f"No occurrences of {context} in the trigram model.")

# Check for specific contexts
get_most_likely_words(("today", "the"), tri_model)
get_most_likely_words(("England", "has"), tri_model)
# Out:
# Most likely words following ('today', 'the'):
# P(company | ('today', 'the')) = 0.1667
# P(price | ('today', 'the')) = 0.1111
# P(public | ('today', 'the')) = 0.0556
# P(European | ('today', 'the')) = 0.0556
# P(Bank | ('today', 'the')) = 0.0556
# Most likely words following ('England', 'has'):
# P(been | ('England', 'has')) = 0.5000
# P(carried | ('England', 'has')) = 0.2500
# P(recently | ('England', 'has')) = 0.2500

# %% [markdown]
# #### Generating text
#
# Create your text generator based on the trigram model. Does the generated text start to feel a bit more sound?

# %%
# your code here
import random

# Sequence start symbol
text = ["I", "am"]  # We need two start symbols for the trigram context

# Generate text until we find the end-of-sequence symbol
while text[-1] != "</s>":
    # Get the previous two words
    context = (text[-2], text[-1])

    if context not in tri_model:
        break  # Stop if the context is unknown in the trigram model

    # Get the list of possible next words and their probabilities
    next_words, probabilities = zip(*tri_model[context].items())

    # Select a word based on the probability distribution
    next_word = random.choices(next_words, weights=probabilities, k=1)[0]

    text.append(next_word)

# Remove the start and end symbols for readability
generated_text = ' '.join([t for t in text if t not in ("<s>", "</s>")])

print(generated_text)
# Out:
# I am confident that substantial development funds will be asked to continue to rise more than made up by 50 mln dlrs .

# %% [markdown]
# ## N-gram models
#
# For larger *n*, we can use NLTK's [n-grams](https://www.nltk.org/_modules/nltk/util.html#ngrams), which allows us to choose an arbitrary *n*.
#
# Create your own 4-gram model.

# %%
# your code here
from collections import defaultdict
from nltk import ngrams
from nltk.corpus import reuters

# Create a placeholder for the 4-gram model
fourgram_model = defaultdict(lambda: defaultdict(lambda: 0))

# Count the frequency of each 4-gram
for sentence in reuters.sents():
    for w1, w2, w3, w4 in ngrams(sentence, 4, pad_left=True, pad_right=True, left_pad_symbol='<s>', right_pad_symbol='</s>'):
        fourgram_model[(w1, w2, w3)][w4] += 1

# Convert counts to probabilities
for context in fourgram_model:
    total_count = sum(fourgram_model[context].values())  # Total occurrences of (w1, w2, w3)
    for w4 in fourgram_model[context]:
        fourgram_model[context][w4] /= total_count  # Normalize to get probabilities

# The model now contains P(w4 | w1, w2, w3)

# %% [markdown]
# #### Likely tuples
#
# Check the most likely words following "today the public".

# %%
# your code here
def get_most_likely_words_4gram(context, model, top_n=5):
    if context in model:
        sorted_words = sorted(model[context].items(), key=lambda x: x[1], reverse=True)
        print(f"Most likely words following {context}:")
        for w4, prob in sorted_words[:top_n]:  # Show top N most likely words
            print(f"P({w4} | {context}) = {prob:.4f}")
    else:
        print(f"No occurrences of {context} in the 4-gram model.")

# Check for the context "today the public"
get_most_likely_words_4gram(("today", "the", "public"), fourgram_model)
# Out:
# Most likely words following ('today', 'the', 'public'):
# P(is | ('today', 'the', 'public')) = 1.0000

# %% [markdown]
# #### Generating text
#
# Create your text generator based on the 4-gram model. Even better, uh?

# %%
# your code here
import random

# Sequence start symbol
text = ["<s>", "<s>", "Portugal"]  # We need three start symbols for the 4-gram context

# Generate text until we find the end-of-sequence symbol
while text[-1] != "</s>":
    context = tuple(text[-3:])  # Use the last 3 words as context (4-gram context)

    if context not in fourgram_model:
        break  # Stop if the context is unknown in the 4-gram model

    # Get the list of possible next words and their probabilities
    next_words, probabilities = zip(*fourgram_model[context].items())

    # Select a word based on the probability distribution
    next_word = random.choices(next_words, weights=probabilities, k=1)[0]

    text.append(next_word)

# Remove the start and end symbols for readability
generated_text = ' '.join([t for t in text if t not in ("<s>", "</s>")])

print(generated_text)
# Out:
# Portugal , which joined the Community in January 1986 .

# %% [markdown]
# #### Prompting the model
#
# Ask the user for some input as a prompt, and make your model continue the input text!

# %%
# your code here
import random

# Function to generate text based on a user-provided prompt
def generate_text_from_prompt(prompt, model, max_length=50):
    # Preprocess the prompt to split into words and add <s> padding if necessary
    prompt_words = prompt.split()
    prompt_words = ["<s>"] * (3 - len(prompt_words)) + prompt_words  # Ensure there are at least 3 starting words
    
    # Generate text based on the prompt until the end-of-sequence symbol is found or max length is reached
    text = prompt_words

    while text[-1] != "</s>" and len(text) < max_length:
        context = tuple(text[-3:])  # Use the last 3 words as context (4-gram context)

        if context not in model:
            break  # Stop if the context is unknown in the 4-gram model

        # Get the list of possible next words and their probabilities
        next_words, probabilities = zip(*model[context].items())

        # Select a word based on the probability distribution
        next_word = random.choices(next_words, weights=probabilities, k=1)[0]

        text.append(next_word)

    # Remove the start and end symbols for readability
    generated_text = ' '.join([t for t in text if t not in ("<s>", "</s>")])
    
    return generated_text

# Example: Ask the user for a prompt
prompt = input("Enter a prompt to continue: ")

# Generate text based on the 4-gram model
generated_text = generate_text_from_prompt(prompt, fourgram_model)

print("Generated text:")
print(generated_text)
# Out:
# Enter a prompt to continue: Portugal
# Generated text:
# Portugal ' s Agriculture Minister Alvaro Barreto that the commission accepted over 785 , 000 vs 1 , 156 , 828 assets 61 . 04 billion dlrs of certificates redeemed to date have cost the state - owned Turkish Petroleum Corp to explore for them .

# %% [markdown]
# ## Perplexity
#
# Now that you have several language models based on different n-gram sizes, you can compare them in terms of perplexity regarding some provided text. Before you do that, however, you might want to apply smoothing to your language models, if you haven't done so already. This will ensure that no sequence gets a probability of zero.

# %% [markdown]
# For the unigram model, we first get the probability of a sequence by multiplying the probability of each token, and then apply the perplexity formula.

# %%
from nltk import word_tokenize

text = input("Sentence: ")
tokens = word_tokenize(text)

# %%
uni_prob = 1
for token in tokens:
    uni_prob *= uni_model[token]

uni_perp = pow(uni_prob, -1/len(tokens))

print("Unigram probability: ", uni_prob, "\nUnigram perplexity: ", uni_perp)

# %% [markdown]
# Do the same for the larger n language models. Don't forget to pad the sentence for each case.
# What do you observe?

# %%
# your code here

# %% [markdown]
# ## Infini-gram
#
# [∞-gram](https://infini-gram.io/) is a Language Model with backoff that can compute unbounded n-gram counts in a very efficient way. Instead of pre-computing n-gram count tables (which would be very expensive), the infini-gram engine can compute ∞-gram (as well as n-gram with arbitrary n) probabilities with millisecond-level latency.
# - You can read more about infini-gram in [Infini-gram: Scaling Unbounded n-gram Language Models to a Trillion Tokens](https://arxiv.org/abs/2401.17377).
# - And you can try it out directly in the Hugging Face [infini-gram](https://huggingface.co/spaces/liujch1998/infini-gram) web interface.
#
# Infini-gram includes indexes on several corpora, which can be queried for the purposes below.

# %% [markdown]
# Infini-gram can be used via its [API endpoint](https://infini-gram.io/api_doc) or via its [Python package](https://infini-gram.io/pkg_doc) (available for Linux distributions).
#
# Infini-gram includes methods for:
# - Counting the number of times an n-gram appears in the corpus.
# - Computing the n-gram probability of the last token conditioned on the previous tokens.
# - Computing the next-token distribution of an (n-1)-gram.
# - Computing the ∞-gram probability of the last token conditioned on the previous tokens, with backoff.
# - Computing the next-token distribution of an ∞-gram, with backoff.
# - Search for documents containing n-gram(s).
#
# Let's try out each of these via the [API endpoint](https://infini-gram.io/api_doc).

# %% [markdown]
# #### Count an n-gram

# %%
import requests

index = 'v4_rpj_llama_s4'
ngram = 'University of Porto'

payload = {
    'index': index,
    'query_type': 'count',
    'query': ngram,
}
result = requests.post('https://api.infini-gram.io/', json=payload).json()

# %%
print("The ngram ", result.get('tokens'), " appears", result.get('count'), "times in", index)

# %% [markdown]
# #### Compute the probability of the last token in an n-gram

# %%
ngram = 'University of Porto is the'

payload = {
    'index': index,
    'query_type': 'prob',
    'query': ngram,
}
result = requests.post('https://api.infini-gram.io/', json=payload).json()

# %%
print("The ngram", result.get('tokens')[0:-1], "appears", result.get('prompt_cnt'), "times, \nfollowed by", result.get('tokens')[-1], "in", result.get('cont_cnt'), "of those, \nfor a probability of", result.get('prob'))

# %% [markdown]
# #### Compute the next-token distribution of an (n-1)-gram

# %%
payload = {
    'index': index,
    'query_type': 'ntd',
    'query': ngram,
}
result = requests.post('https://api.infini-gram.io/', json=payload).json()

# %%
for t in result.get('result_by_token_id').values():
    print(f"{t.get('token'):15}", "appears", f"{t.get('cont_cnt'):3}", "times, for a probability of", t.get('prob'))

# %% [markdown]
# #### Compute the ∞-gram probability of the last token
#
# Comparing n-gram with ∞-gram probabilities:

# %%
ngram = 'since University of Porto is the'

payload = {
    'index': index,
    'query_type': 'prob',
    'query': ngram,
}
result = requests.post('https://api.infini-gram.io/', json=payload).json()

# %%
print(result.get('prob'))

# %%
payload = {
    'index': index,
    'query_type': 'infgram_prob',
    'query': ngram,
}
result = requests.post('https://api.infini-gram.io/', json=payload).json()

# %%
print("The longest found suffix is '", result.get('longest_suffix'), "' and appears", result.get('prompt_cnt'), "times, \nfollowed by", result.get('tokens')[-1], "in", result.get('cont_cnt'), "of those, \nfor a probability of", result.get('prob'))

# %% [markdown]
# #### Compute the ∞-gram next-token distribution
#
# Comparing n-gram with ∞-gram next-token distributions:

# %%
ngram = 'since University of Porto is the'

payload = {
    'index': index,
    'query_type': 'ntd',
    'query': ngram,
}
result = requests.post('https://api.infini-gram.io/', json=payload).json()

# %%
result.get('result_by_token_id')

# %%
payload = {
    'index': index,
    'query_type': 'infgram_ntd',
    'query': ngram,
}
result = requests.post('https://api.infini-gram.io/', json=payload).json()

# %%
print("The longest found suffix is '", result.get('longest_suffix'), "' and appears", result.get('prompt_cnt'), "times")
for t in result.get('result_by_token_id').values():
    print(f"{t.get('token'):15}", "appears", f"{t.get('cont_cnt'):3}", "times, for a probability of", t.get('prob'))

# %% [markdown]
# #### Search for documents containing n-gram(s)

# %%
ngram = 'University of Porto'

payload = {
    'index': index,
    'query_type': 'search_docs',
    'query': ngram,
    'maxnum': 3,
}
result = requests.post('https://api.infini-gram.io/', json=payload).json()

# %%
len(result.get('message'))

# %%
for d in result.get('documents'):
    print(d.get('doc_ix'))
    for s in d.get('spans'):
        print(s[0])

# %% [markdown]
# #### Generating text
#
# By exploring ∞-gram next-token distributions, we can create a text generator that takes into account these probabilities. Can you do it?
#
# (Note that by relying on the API endpoint we end up needing to make successive calls to the API, which is pretty slow.)

# %%
# your code here
